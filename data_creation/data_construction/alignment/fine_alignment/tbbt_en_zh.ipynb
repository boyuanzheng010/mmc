# %%
import pickle as pkl
import json
from collections import defaultdict
import jiwer
from copy import deepcopy
from tqdm import tqdm
import xlsxwriter
import re

# %%
from utils.preprocessing import organize_coarse_alignment_by_seasons
from utils.preprocessing import fetch_subsets

# %%
# Define sentence transformation
transformation = jiwer.Compose([
    jiwer.ToLowerCase(),
    jiwer.RemoveMultipleSpaces(),
    jiwer.ExpandCommonEnglishContractions(),
    jiwer.RemovePunctuation(),
    jiwer.Strip()
])

# %% [markdown]
# ## Load Source file

# %%
# Set File Path
en_subtitle_path = "../../source_data/subtitles/en_fa/en_subtitles.pkl"
other_subtitle_path = "../../source_data/subtitles/en_fa/fa_subtitles.pkl"
transcript_path = "../../source_data/transcripts/tbbt/tbbt_transcripts.pkl"
coarse_alignment_path = "../coarse_alignment/results/tbbt_en_fa.pkl"
root_path = "results/tbbt_en_fa/"

# Load Data
with open(en_subtitle_path, 'rb') as f:
    all_en_subtitles = pkl.load(f)
with open(other_subtitle_path, 'rb') as f:
    all_other_subtitles = pkl.load(f)
with open(transcript_path, 'rb') as f:
    all_transcripts = pkl.load(f)

# %% [markdown]
# # Section 1: Coarse-Grain Alignment
# Use string match to fetch relevant index of open subtitle for each episode
# The code for coarse alignment locates at "../coarse_alignment/align_transcript_subtitle.py"
# The alignment results locates at "../coarse_alignment/results/"

# %%
with open(coarse_alignment_path, 'rb') as f:
    temp = pkl.load(f)
    coarse_alignments = organize_coarse_alignment_by_seasons(temp)

# %% [markdown]
# # Section 2: Fine-Grained Alignment
#
# In this section, we fetch alignment within one episode using the course alignment indexs fetch in the last section.
#
# This include the following parts:
#
# 2.1: Fetch transcript episode and open subtitle subset
# 2.2: Exact String Match (Use as the seed, since it is more accurate)
# 2.3: Substring Exact Match (Sliding Window Algorithm)
# 2.4: Merge the alignment result of 2.2, 2.3 and filter by the index

# %% [markdown]
# ## Part 2.1: Fetch Subsets

# %%
# An example of fetch_subset function
(en_subtitle, other_subtitle, tbbt_episode) = fetch_subsets(
        episode=all_transcripts,
        en_subtitle=all_en_subtitles,
        zh_subtitle=all_other_subtitles,
        results=coarse_alignments,
        season_id=1,
        episode_id=3,
        bias=200
    )

for a, b in zip(en_subtitle, other_subtitle):
    print(a, b)
# Out:
# Sheldon, this is not your home. اينجا خونه تو نيست
# This is not anyone's home. This is a swirling vortex of entropy. اين خونه هيچ کسي نيست اينجا گردابي قلتان از بي نظميه
# When the transvestite lived here, you didn't care how he kept the place. ببينم همسايه قبلي اينجا زندگي ميکرد وضعيت اينجا برات مهم نبود
# Because it was immaculate. به خاطر اين که ايشون خيلي معصوم بودند
# I mean, you open that man's closet it was left to right, evening gowns, cocktail dresses and his police uniforms. يعني در کمد لباسشو که باز ميکردي از چپ به راست لباس راحتي عصرونه لباس مهموني و بعد هم لباس يونيفورم پليسي شو گذاشته بود
# What were you doing in his closet? تو با کمد لباس اون چي کار داشتي؟
# I helped him run some cable for a webcam. داشتم کمکش ميکردم که براي وب کم سيم بکشيم
# This just arrived. Brought this up. Just now. سلام پني ، همين الان آورديمش بالا همين حالا
# Was it hard getting up the stairs? بالا آوردنش از پله ها خيلي سخت بود
# We'll get out of your hair. خب ما زحمتو کم ميکنيم
# Okay, great. Thank you again. باشه ، بازم ممنون
# I just want you to know that you don't have to live like this. پني ، من فقط ميخوام بدوني مجبور نيستي اينجوري زندگي کني
# I'm here for you. من به خاطر تو اينجام
# What's he talking about? در مورد چي حرف ميزنه
# It's a joke. اين يه جوکه
# I don't get it. من متوجه نشدم
# yeah, he didn't tell it right. آره ، درست تعريف نکرد
# Penny's sleeping. پني خوابه
# Are you insane? ديونه شدي ؟
# You can't break into a woman's apartment in the middle of the night and clean. تو حق نداري همينطوري بياي تو آپارتمان يه خانوم اونم نصف شب براي تميزکاري
# I had no choice. چاره اي نداشتم نميتونستم بخوابم در حالي که ميدونستم
# I couldn't sleep knowing that just outside my bedroom was our living room and outside our living room was that hallway and immediately adjacent to that hallway was this. دقيقا بيرون اتاق خواب ما نشيمنه و بيرون اتاق نشيمن راهرو هستش و دقيقا کنار راهرو ...
# Do you realize that if Penny wakes up there is no reasonable explanation as to why we're here? ميدوني اگه پني بيدار بشه هيچ دليل قانع کننده اي براي اينجا بودن نداريم
# I just gave you a reasonable explanation. من الان يه دليل قانع کننده به تو گفتم
# No, no. you gave me an explanation. نه ، نه تو فقط يه توضيح به من دادي
# It's reasonableness will be determined by a jury of your peers. قانع کننده بودن آن توسط هيئت داوراني که هم سن تو هستند تعيين ميشه
# Don't be ridiculous. I have no peers. اينقدر مسخره نباش من هم سن وسالي ندارم
# Sheldon, we have to get out of here. ما بايد از اينجا بريم
# You might want to speak in a lower register. ممکنه لازم باشه با صداي بم تري حرف بزني
# Evolution has made women sensitive to high-pitch noises while they sleep so that they'll be roused by a crying baby. سير تکامل زن ها رو حساس به صداهاي زير در خواب کرده واينطوري هر وقت که بچه صدا ميکنه ازخواب ميپرن
# If you want to avoid waking her, speak in a lower register. اگه ميخواي بيدار نشه با صداي بم تري صحبت کن
# That's ridiculous! مسخرس!
# No, that's ridiculous. نه "اين مسخرس"
# Fine. قبول
# I accept your premise. Now, please let's go. من پيشنهادتو قبول کردم حالا لطفا بيا بريم
# I'm not leaving until I'm done. من تا وقتي که کارم تموم نشه نميام
# If you have time to lean, you have time to clean. اگه وقت براي لم دادن داري حتما براي تميزکاري هم داري
# Oh, what the hell. اه ، عجب گندي شده
# I have to say I slept splendidly. بايد اعتراف کنم ديشب عالي خوابيدم
# Granted not long, but just deeply and well. گرچه طولاني نبود ، اما خيلي عميق وعالي بود
# I'm not surprised. اصلا سورپرايز نشدم
# A well-known folk cure for insomnia is to break into your neighbor's apartment and clean. يک راه خيلي مرسوم وشناخته شده براي درمان بي خوابي دزدکي وارد آپارتمان همسايه شدن و تميز کردن اونجاست
# Sarcasm? طعنه ميزني؟
# Granted, my methods may have been somewhat unorthodox but the end result will be a measurable enhancement to Penny's quality of life. قبول ميکنم ، که روش هاي من يه جورايي نامتعارفه ولي به نظرم نتيجه نهايي خيلي عالي ميشه -و تاثير زيادي روي زندگي پني خواهد گذاشت
# You've convinced me, maybe we should sneak in and shampoo her carpet. داري منو متقائد ميکني پس شايد امشب بايد دزدکي بريم تو و فرششو شامپو بزنيم
# You don't think that crosses a line? فکر نميکني اين کار از مرز رد شدنه؟
# Yes. چرا
# For God's sake, Sheldon do I have to hold up a sarcasm sign every time I open my mouth? به خاطر خدا من بايد هر وقت دهنم رو باز ميکنم يه تابلو بگيرم دستم که روش نوشته طعنه
# You have a sarcasm sign? مگه تابلويي که روش نوشته طعنه ، داري؟
# No, I do not have a sarcasm sign. نه ، من چنين تابلويي ندارم
# You want some cereal? صبحانه ميخوري؟
# I feel so good today, I'm gonna choose from the low-fiber end of the shelf. من امروز خيلي سرحالم امروز ميخوام از نوع کم فيبر که در آخر طبقه هست استفاده کنم
# Hello, Honey Puffs. سلام هاني پاف
# Penny's up. پني بيدار شد
# You sick, geeky bastards! حرومزاده هاي خرخون ديوونه
# How did she know it was us? از کجا فهميد ما بوديم
# I may have left a suggested organizational schematic for her bedroom closet. فکر کنم من يک دستور العمل سازماندهي پيشنهادي اونجا جا گذاشتم براي مرتب کردن کمد اتاق خوابش
# Leonard? This is gonna be bad. خداي من خيلي بد ميشه
# Goodbye, Honey Puffs. خداحافظ هاني پاف سلام بيگ بران
# You came into my apartment while I was sleeping? شما ديشب در حالي که من خواب بودم اومديد تو آپارتمان من
# Yes, but only to clean. بله ، ولي فقط براي تميز کردن
# Really more to organize, you're not actually dirty, per se. در اصل بيشتر براي منظم کردن چون که تو خودت واقعا کثيف نيستي
# Give me back my key. کليد منو پس بده
# I'm very, very sorry. من خيلي خيلي متاسفم
# Do you understand how creepy this is? ميدوني اين کار چقدر وحشتناکه
# Yes, we discussed it at length last night. بله ، البته ديشب مفصل در موردش صحبت کرديم
# In my apartment? While I was sleeping? توي آپارتمان من اونم موقعي که من خواب بودم
# And snoring. And that's probably just a sinus infection. و خوروپف ميکردي اين ممکنه مال آسيب سينوس هات باشه
# But it could be sleep apnea. البته ميتونه مشکل تنفسي هم باشه
# You might wanna see an otorhinolaryngologist. ممکنه لازم باشه بري پيش يک متخصص گوش و حلق و بيني
# The throat doctor. يک دکتر گلو
# And what kind of doctor removes shoes from asses? و چه دکتري ميتونه يه کفشو از توي کون آدم دربياره
# Depending on the depth that's either a proctologist, or a general surgeon. خب بستگي داره به عمقش ميتوني پيش يه متخصص روده بري يا يک جراح عمومي
# No, Penny- فکر کنم احساس تو
# I think what you're feeling is valid and maybe later today when you're feeling less, for lack of a better word, violated maybe we can talk about this. کاملا منطقيه و ممکنه چند دقيقه ديگه وقتي يه کمي احساست واعصابت آروم تر و نرم تر شد در مورد اين قضيه بيشتر صحبت بکنيم
# Stay away from me. بکش کنار
# Sure. That's another way to go. البته اينم يه راهه براي رفتن
# Penny, Penny, hold on. پني ، پني يه لحظه
# Just to clarify because there will be a discussion when you leave. فقط براي اين که قضيه روشن بشه و چون تو که بري يه جروبحث خواهيم داشت
# Is your objection solely to our presence in the apartment while you were sleeping or do you also object to the imposition of a new organizational paradigm? بگو ببينم اعتراض تو فقط به خاطر حضور ما در آپارتمان بوده يا تو نسبت به برنامه نظافتي که برات نوشتيم هم معترضي
# Well, that was a little non-responsive. ظاهرا براش جوابي نداشت
# You are going to march yourself over there right now and apologize. همين الان تن لشتو ميبري اونجا و عذرخواهي ميکني
# What's funny? کجاش خنده دار بود؟
# That wasn't sarcasm? مگه کنايه نزدي
# Boy, you are all over the place this morning. اوه ، پسر امروز هر يه دقيقه يه چيزي ميگي
# I have a Master's and two Ph. Ds, I should not have to do this. من يک فوق ليسانس و دوتا دکتري دارم نبايد اين کارو انجام بدم
# I'm truly sorry for what happened last night. من واقعا به خاطر اتفاق ديشب متاسفم
# I take full responsibility. من تمام مسئوليتشو به عهده ميگيرم
# I hope that it won't color your opinion of Leonard who is not only a wonderful guy, but also, I hear, a gentle and thorough lover. و اميدوارم که اين مسئله ذهنيت تو رو نسبت به لئونارد خطشه دار نکنه که اون نه تنها شخص بسيار شگفت انگيزيه بلکه من شنيدم متشخص و يه عاشق واقعيه
# I did what I could. هر کاري ميتونستم کردم
# Hey, Raj. سلام ، راج
# Hey, I don't know if you heard about what happened with Leonard and Sheldon but I'm really upset about it. هي ، گوش کن نميدونم درمورد اتفاق ديشب چيزي ميدوني يا نه اما من به خاطر اون خيلي ناراحتم
# I mean, they let themselves into my place, and then they cleaned it. منظورم اين که... اونا همينطوري به خودشون اجازه دادن بيان تو خونه من و بد تميزش کنند ،اصلا باورت ميشه؟
# Can you even believe that? خيلي عجيب ، غريبه؟
# How weird is that? She's standing very close to me. خيلي نزديک به من ايستاده
# Oh, my. She does smell good. اه، خداچه بويخوبيميده
# What is that? بوي چيه ، وانيل؟
# Vanilla? you know? ميدوني من از کجا اومدم
# Where I come from, someone comes into your house at night, you shoot. Okay? تو شهر من اگه کسي شب بياد داخل خونت بهش شليک ميکنند
# And you don't shoot to wound. اونم نه به قصد زخمي کردن
# I mean, all right, my sister shot her husband, but it was an accident, they were drunk. منظورم اين که ، خيلي خب ببين خواهر من به شوهرش شليک کرد البته اين يه حادثه بود اونا مست بودند
# What was I saying? صبر کن ، چي داشتم ميگفتم؟
# She's so chatty. چقدر حرف ميزنه
# Maybe my parents were right. شايد حق با خانوادم باشه
# Maybe I'd be better off with an Indian girl. شايد من با يه دختر هندي راحت تر باشم
# We'd have the same cultural background and my wife could sing to my children the lullabies my mother sang to me. اينطوري يک پيش زمينه فرهنگي داريم و زن من ميتونه همون لالايي هايي که براي من خونده برا بچه هام بخونه.
# It's obvious they meant well. مطمئنا اونا نيت خير داشتند ولي...
# I'm having a really rough time. من الان در شرايط واقعا بدي هستم من با دوست پسر قبليم بهم زدم
# Like I said I broke up with my boyfriend and it's freaking me out. و...
# I mean, just because most of the men I've known happened to be jerks doesn't mean I should just assume Leonard and Sheldon are. از اونجا که اکثر مردهايي که تو زندگيم ديدم آشغال بودند... دليل نميشه که فکرکنم شلدون و لئونارد هم همينطورند
# She asked me a question. I should probably nod. اون داره از من يه سئوال ميپرسه فکر کنم بهتره يه سري تکون بدم
# That's exactly what I thought. دقيقا همينطوري فکر ميکردم
# Thank you for listening. You're a doll. ممنونم که گوش دادي تو مثل عروسکي
# Turn your pelvis. لگنت رو بچرخون
# Grab a napkin, homey, you just got served. دستمال ها رو باز کنيد دوستان ضيافت تمام شد
# It's fine. you win. باشه ، تو بردي
# What's his problem? مشکلش چيه؟
# His imaginary girlfriend broke up with him. دوست دختر خياليش باش قهر کرده
# Been there. منم تو اين شرايط بودم
# Sorry I'm late, but I was in the hallway, chatting up Penny. ببخشيد دير شد چون داشتم توي راهرو با پني حرف ميزدم
# you? تو راجش کوترپالي؟
# Rajesh Koothrappali spoke to Penny? تو با پني حرف ميزدي
# Actually, I was less the chatter than the chattee. در اصل من بيشتر گوش ميدادم تا حرف بزنم
# Is she still mad at me? هنوز از دست من ناراحته؟
# Well, she was upset at first but probably because her sister shot somebody. راستش اولش خيلي نارحت بود احتمالا چون خواهرش به يه نفر شليک کرده بود
# Then there was something about you, and then she hugged me. اما بعدش يه چيزي در مورد تو گفت و بعد هم من رو بغل کرد
# She hugged you? تو رو بغل کرد؟
# How did she hug you? چطوري تو رو بغل کرد؟
# Is that her perfume I smell? اين بوي عطر اونه
# Intoxicating, isn't it? مست کنندست ، مگه نه؟
# What's going on? داري چي کار ميکني؟
# Here's the thing: الان ميگم
# "Penny, just as Oppenheimer came to regret his contributions to the first atomic bomb so too I regret my participation in what was at the very least, an error in judgment. دقيقا همونطور که اوپن هيمر آمد تا براي شرکت داشتنش در ساخت اولين بمب اتم ابزار پشيموني کنه من هم آمده ام از شرکت داشتنم در ماجرايي که
# The hallmark of the great human experiment is the willingness to recognize one's mistakes. نشانه تجربه داشتن مردان بزرگ تمايل آن ها براي درک و پذيرش اشتباه ديگران است
# Madam Curie's discovery of radium turned out to have great potential even though she would later die a slow, painful death from radiation poisoning. مثل اشتباه مادام کوري که راديوم را کشف کرد منجر به کشف يه پتانسيل علمي بسيار بزرگ شد گرچه خودش بعدها به يک مرد تدريجي و مرگبار دچار شد
# Another example, from the field of Ebola research-" مثال ديگر در زمينه تحقيقات اِبولا
# We're okay. ما با هم مشکلي نداريم
# Six two-inch dowels? سيم دو سر شصت و دو اينچي -بررسي شد
# One package Philips head screws? يه بسته پيچ فيليپس
# Check. بررسي شد
# Guys, seriously, I grew up on a farm, okay? بچه ها جدي ميگم من تو يه مزرعه بزرگ شدم
# I rebuilt a tractor engine when I was, like, 12. من موتور يه تراکتور وقتي دوازده سالم بود بازسازي کردم
# I think I can put together a cheap Swedish media center. من فکر کنم بتونم يه مديا سنتر ارزون سوئدي کنار هم قرار بدم
# Please, we insist. It's the least we can do, considering- نه لطفا خواهش ميکنيم اين کمترين چيزيه که ما ميتونيم انجام بديم در رابطه با
# Considering what? در رابطه با چي؟
# How great this place looks? که چقدر اينجا قشنگه
# Oh, boy, I was afraid of this. اوه ، پسر من از همين ميترسيدم -چي؟
# These instructions are a pictographic representation of the least imaginative way to assemble these components. اين دستور العمل يک ارائه تصويري... در ساده ترين راه قابل تصور براي سوار کردن اين اجزاست
# This right here is why Sweden has no space program. اينجا دقيقا به همين دليل سوئد برنامه هاي فضايي نداره
# It looked pretty good in the store. خب ، در انبار اين خيلي خوب به نظر مياد
# It is an inefficient design. اين يک طراحي خيلي کم بازدست مثلا پني يه تلويزيون فلت داره
# For example, Penny has a flatscreen TV which means all this space behind it is wasted. و اين يعني تمام فضاي پشت سر اون هدر ميره
# We could put her stereo back there. ما ميتونيم استريوهاشو بزاريم اينجا
# And control it how? و چطور کنترلش کنيم؟
# Run an infrared repeater, photocell here, emitter here, easy-peasy. يه ريپيتر اينفرورد نصب ميکنيم فوتوسل شو ميزاريم اينجا ، اِميتر هم اينجا به همين سادگي
# Good point. How will you cool it? چطور ميخواي خنکش کني؟
# Guys, I got this. هي بچه ها من حلش ميکنم
# Hang on, Penny. صبر کن پني
# How about fans? چطوره فن بزاريم؟
# Here and here. اينجا و اينجا
# Also inefficient, and might be loud. اون بازدش کمه و در ضمن ممکنه صداش زياد باشه
# How about a liquid cooler? A little aquarium pump here. چطوره از مايع خنک کننده استفاده کنيم يه پمپ آکواريوم کوچک ميزاريم اينجا
# Run some quarter-inch PVC- يه لوله پي.وي.سي يه چهارم اينچ...
# Guys, this is actually really simple. بچه ها ، اين قضيه واقعا خيلي سادست
# Hold on, honey, men at work. صبر کن ، عزيزم آقايون مشغول کارند
# PVC comes here. پي.وي.سي از اينجا مياد پايين
# Maybe a little corrugated sheet metal as a radiator here. شايد يه کمي فلز چين دار به عنوان رادياتور
# Show me where we put a drip tray, a sluice and a overflow reservoir? آره؟ بگو ببينم حالا آبچکونو ، دريچه تخليه و مخزن سرريز رو کجا ميزاري
# If water's involved, we'll ground the crap out of the thing. اگه بخوايم از آب استفاده کنيم که بايد کلا اين داستان رو بندازيم دور
# Guys, it's hot in here. I think I'll just take off all my clothes. اگه مشکل گرما باشه فکرکنم بتونم لباس هام رو دربيارم
# Oh, I've got it. آهان ، فهميدم
# What if we replaced panels A, B and F and crossbar H with aircraft-grade aluminum? اگر بخوايم... h و ميله ارزي f و b و a پنل هاي را از جنس آلومينيوم هواپيما بسازيم چي
# Entire thing's one big heat sink. آفرين بعد همه اين مجموعه يه چاه حرارتي ميشه
# Perfect. تو و شلدون به اوراقي بريد و...
# Leonard and Sheldon, go to the junkyard and pick up 6 square meters of aluminum. و يک متر مربع از آلومينيوم دور ريز شده پيدا کنيد
# Raj and I will get the oxyacetylene torch. من و راج هم ميريم يه مشعل اسيتيلن پيدا ميکنيم
# Meet in an hour? يه ساعت ديگه همديگرو اينجا ميبينم
# Done. قبول
# Okay, this place does look pretty good. باشه ، اينجا خيلي خوشگل به نظر ميرسه مترجم :
# all right,just a few more feet. خيلي خوب ، فقط چند فوت ديگه مونده و ...
# And... here we are,gentlemen,the gates of elzebob. آقايان ما رسيديم دروازه شيطان
# Good lord. خداي مهربان
# Don't panic. This is what the last 97 hours have been about. هيجان زده نشيد الان نود و هفت ساعته که ماداريم به اينجا ميرسيم
# Stay frosty. بي حرکت بمونيد اينجا يه لشکر از اجنه مسلح در طرف ديگر دروازه در کمينند
# There's a horde of armed goblins on the other side of that gate guarding the sword of asaroth. و از شمشير آزاروس محافظت ميکنند
# Warriors,unsheathe your weapons. Magic wielders,raise your wands. پيش قراولان جادويي گرزها را بالا ببريد
# Lock and load. آماده حمله
# Raj,blow the gates. راج ، دروازه رو منهدم کن
# Blowing the gates. منهدم ميکنيم
# Control,shift... b! کنترل shift... B!
# oh,my god,so many goblins! اوه ، خداي من ، چقدر اجنه
# Don't just stand there,slash and move,slash and move! همين طوري نايست بکش و برو جلو
# Stay in formation! آرايش نظاميتون رو حفظ کنيد
# Leonard,you got one on your tail. لئونارد ، يه اجنه رو دمته
# That's all right,my tail's prehensile- به دمم گير کرده آلان ميدازمش پايين
# I'll swat him off. I got him,leonard. من کشتمش لئونارد
# Tonight I spice my mead with goblin blood. امشب من نوشيدنيمو از خون اجنها درست ميکنم
# Raj,no,it's a trap! They're flanking us! راج ، نه ، اين يه تله است دارن از کنار بهمون حمله ميکنن
# He's got me! آه من رو گرفتن
# Sheldon,he's got raj. Use your sleep spell! شلدون راج رو گرفت از جادوي خوابت استفاده کن
# I've got the sword of asaroth! من شمشير آزاروس رو گرفتم
# Forget the sword,sheldon,help raj! شمشيرو بيخيال به راج کمک کن
# There is no more sheldon. I am the sword master! ديگه شلدوني وجود نداره من پادشاه شمشيرم
# Leonard,look out! Damn it,man,we're dying here! لئونارد نگاه کن لعنت به تو پسر ما داريم ميميريم
# the bastard teleported! پست فطرت ديگه اصلا اينجا نيست
# He's selling the sword of asaroth on ebay. ميفروشه e-bay داره شمشير ازاروس رو در
# You betrayed us for money? تو بخاطر پول به ما خيانت کردي؟
# Who are you? تو ديگه کي هستي
# I'm a rogue night elf. من يه جن شب گردم
# Don't you people read character descriptions? مگه شما مشخصات شخصي تيمم رو نخوندين
# Wait,wait,wait! Somebody just clicked "buy it now. صبرکن ، صبرکن يه نفر همين آلان شمشير رو خريد
# " I am the sword master! من پادشاه شمشيرم
# Ooh,I'm all sweaty. اوه خيس عرق شديم
# Anybody want to log on to second life and go swimming? کسي ميخواد وارد زندگي دوم بشيم و بريم شنا
# I just built a virtual pool. من يک استخر مجازي ساختم
# I can't look at you or your avatar right now. نه من اصلا حوصله ديدن خودت ياعکستوندارم
# sounds like your neighbor's home. انگار همسايتون خونست
# Don't forget the mail you took accidentally on purpose so you'd have an excuse to talk to her. نامه اي که بطور اتفاقي به بهانه ي صحبت با اون برداشتي يادت نره
# Oh,right,right,right,right. اوه ، آره ، آره ، آره
# Stealing snail mail- دزديدن نامه هاي پستي ... يه .روش خيلي قديمي . خوش مياد
# Penny,the mailman,did it again... he... oh,sorry. ، پني ...پستچي دوباره ببخشيد
# Um,oh,hi,leonard. This is doug. سلام ، لئونارد اين داگه
# Doug,this is my neighbor leonard. داگ ، اين همسايم لئونارده
# What's up,bro? چي شده داش؟
# Not much... bro. هيچي .داش
# Is everything okay? همچي مرتبه؟
# Yeah,no,I just... I got your mail again. Here. آره فقط من دوباره نامتو اينجا پيدا کردم
# Thank you. I've got to talk to that mailman. خيلي ممنون من بايد با پستچي يه صحبتي بکنم
# Oh,no,that's probably not such a good idea. اوه ، نه ، فکر نکنم ايده خوبي باشه
# You know,civil servants have a documented propensity to,you know,snap,so... okay. کارمندان دولتي کاغذ بازي رو دوست دارند ...ميدوني که ...شيطونه ميگه بزنم باشه .
# Well,thank you again. بازم ممنونم
# No problem. خواهش ميکنم . خدافظ
# Oh,and bye... bro. اه ، وخدافظ داداش
# Penny for your thoughts. ذهنت رو يه قرون مي خرم
# Penny's fine. The guy she's kissing is really fine. پني هم خوبه اون يارو هم که داشت ماچش ميکرد هم خوبه
# Kissing,what kind of kissing? بوس ، چه مدل بوسي؟ لوپ ؟ لب؟
# Cheeks? معصومانه؟ عاشقانه؟
# What is wrong with you? تو چه مرگيته
# I'm a romantic. من خيلي رمانتيکم
# Please don't tell me that your hopeless infatuation is devolving into pointless jealousy. لطفا نگو که شيفتگي هاي نااميدانه ات جاشو به حسادت هاي بي مورد داده
# I'm not jealous. I'm just a little concerned for her. من حسود نيستم من فقط نگرانشم
# I didn't like the look of the guy that she was with. من از اين يارو خوشم نيومد
# Because he looks better than you? چون از تو بهتره ؟
# He was kind of dreamy. يارو خيلي رويايي بود
# Well,at least now you can retrieve the black box from the twisted, olsmdering wreckage that was once your fantasy of dating her and analyze the data so that you don't crash into geek mountain. کمترين کاري که ميتوني بکني اينکه اطلاعات جعبه سياه بازمانده از خرابهاي آتش سوزي برجهاي دوقلو رو بازخواني کني يعني اينکه يه قرار ملاقات باهاش بزاري
# I di. من مخالفم
# Greesa love is not a sprint,it's a marathon- عشق دوي سرعت نيست دوي ماراتونه يه تعقيب و گريز ناجوانمردانه که فقط زماني به آخرميرسه که او در دستان تو باشه و يا اينکه حالتو با يه اسپري فلفل جا اورده باشه
# a relentless pursuit that only ends when she falls into your arms... or hits you with the pepper spray. No,I'm done with penny. من ديگه با پني کاري ندارم
# I'm going to be more realistic and go after someone my own speed. ميخوام يک بيشتر واقعبين باشم و برم دنبال کسي در شأن خودم
# Like who? مثلا کي؟
# I don't know... olivia geiger. نميدونم اوليوياگايگر
# The dietician at the cafeteria with the limp and the lazy eye? همون دختر شله ي رژيم دار که تو کافه ترياست و تنبلي چشم هم داره
# Oh,I don't think you have a shot there. فکر نميکنم اونجا بتوني چيزي شکار کني
# I have noticed that leslie winkle recently started shaving her legs. من اطلاع پيدا کردم که اخيرا لسلي وينکل شروع کرده به تيغ زدن موهاي پاهاش
# Now given that winter is coming, one can only assume she's signaling sexual availability. و از اونجا که تازه زمستان داره شروع ميشه فقط به اين دليله ميتونه باشه که داره خودشو براي سکس آماده ميکنه
# I don't know. You guys work in the same lab. من نميدونم شما تو يه آزمايشگاه کار ميکنيد
# There are pitfalls. يه تله اي تو کاره
# Trust me,I know. باور کنيد من ميدونم
# When it comes to sexual harassment law,I'm a bit of a self taught expert. وقتي قوانين آزار جنسي پيش مياد من يه جورايي به طور خودآموز حرفه ايم
# Look,howard,if I were to ask leslie winkle out,it would just be for dinner. خوب ببينم اگه من رفتم از لسلي وينکل دعوت کردم
# I'm not going to walk into the lab,ask her to strip naked and dance for me. اين ميتونه فقط براي شام باشه نه ، من همينطوري سر نميدازم برم تو يه آزمايشگاه و ازش بخوام که لباساشو دربياره و برام برقصه
# Oh,then you're probably okay. اوه پس تو احتمالا اوضاعت خوبه
# Hello,leslie. Hi,leonard. سلام ، لسلي سلام ، لئونارد
# Leslie,I would like to propose an experiment... من ميخوام که يه تجربه اي رو پيشنهاد کنم
# goggles,leonard. عينک ، لئونارد باشه
# Right. Leslie,I would like p toropose an experiment. من ميخوام يه تجربه اي رو پيشنهاد کنم
# I've done it. About two seconds. 2. 6 for minestrone. من اينکارو انجام دادم حدود 2.6 دهم ثانيه براي يه سوپ غليظ طول ميکشه
# anyway,I was thinking more of a bio- social exploration with a neuro- chemical overlay. بهرحال من بيشتر داشتم به يک تاثيرپذيري هرموني ، عصبي فکر ميکردم تا يک آزمايش علمي
# Wait,are you asking me out? صبر کن ببينم تو داري از من تقاضا ميکني؟
# I was going to characterize it as the modification of our colleague- slash- friendship paradigm with the addition of a date like component, but we don't need to quibble over terminology. من خواستم قضيه رو از طريق الگوي دوستي - همکلاسي خودمون
# What sort of experiment would you propose? چي ميخواي پيشنهاد کني؟
# There's a generally accepted pattern in this area. به طور عموم يه روش پذيرفته شده در اين رابطه وجود داره
# I would pick you up,take you to a restaurant. من شما را مي برم به يه رستوران
# Then we would see a movie, probably a romantic comedy featuring the talents of hugh grant or sandra bullock. بعد ما يه فيلم ميبينيم احتمالا يه فيلم رمانتيک با هنر نمايي هاگ گرانت و ساندرا بلاک
# Interesting. جالبه و آيا قبول داري
# And would you agree that the primary way we would evaluate either the success or failure of the date would be based on the biochemical reaction during the good night kiss? اولين راه براي فهميدن موفقيت يا شکست يه قرار عاشقانه براساس عکس العمل هاي بيوشيمايي در هنگام بوس آخر شب بنا شده
# Heart rate,pheromones,etc. ضربان قلب، هرمون ها و غيره بله
# Why don't we just stipulate that the date goes well and move to the key variable? خوب ، پس اول بزار ببينيم قرار عاشقانمون جوابم ميده بعد ميريم سراغ متغييرهاي کليدي
# You mean kiss you now? يعني آلان ببوسمت؟
# Can you define the parameters of the kiss? ميتوني پارامترهاي يه بوس رو برا من تعريف کني؟
# shall I count down from three? تا سه بشمارم؟
# No,I think it needs to be spontaneous. نه ، فکر کنم بهتره ناگهاني باشه
# What do you think? خوب چي فکر ميکني؟
# You proposed the experiment. تو پيشنهاد اين آزمايش رو دادي
# I think you should present your findings first. پس بهتره تو اول برداشت رو بگي
# Fair enough. عادلانه است
# On the plus side,it was a good kiss. از ديد مثبت بوس خوبي بود
# Reasonable technique,no extraneous spittle. تکنيک قابل قبولي داشت تف اضافي نداشت
# On the other hand,no arousal. و از لحاظ ديگه هيچ تحريکي نداشت
# None? هيچي؟
# None. هيچي
# Well,thank you for your time. به خاطر وقتت ممنونم خواهش ميکنم
# None at all? هيچ تحريکي ؟
# Sheldon,if you were a robot,and I knew and you didn'T... ... would you want me to tell you? شلدون ، اگه تو يه روبات بودي درحالي که من ميدونستم ولي خودت نه دوست داشتي بهت ميگفتم که يه رباتي؟
# That depends. بستگي دار به اينکه
# When I learn that I'm a robot... will I be able to handle it? وقتي ...من فهميدم که يه روباتم قادر به انجامش هستم يا نه؟
# Maybe- شايد ... در ضمن تاريخچه علمي تخيلي از تو طرفداري نميکنه
# although the history of science fiction is not on your side. Okay,uh,let me ask you this- باشه بزار من ازت يه چيزي بپرسم وقتي من فهميدم که يه روباتم آيا مجبور به رعايت سه قانون ازيموف در مورد روباتيک هستم؟
# when I learn that I'm a robot, would I be bound by asimov's three laws of robotics? You might be bound by them right now. تو احتمالا همين الان هم درحال رعايت اونهايي
# That's true. راست ميگه آيا تا حالا به يه انسان آسيب زدي
# Have you ever harmed a human being or through inaction allowed a human being to come to harm? يا در اثر بي حرکت ماندن باعث اسيب يه انسان شدي
# Of course not. البته که نه ايا تا حالا به خودت اسيب زدي
# Have you ever harmed yourself or allowed yourself to be harmed except in cases where a human being would have been endangered? يا اجازه دادي که آسيب ببيني مگه جون يه ادم در خطر بوده باشه
# Well,no. I smell robot. خوب ، نه بوي روبات احساس ميکنم
# Hey,what's going on? هي چي شده؟
# Internet's been down for half an hour. اينترنت نيم ساعته که قطع شده
# Also,sheldon may be a robot. در ضمن ، شلدون هم ممکنه يه روبات باشه
# So how'd it go with leslie? اوضاع با لسلي چطور بود؟
# Oh,we tried kissing,but the earth didn't move. اوه ، ما سعي کرديم همديگه رو ببوسيم اما زمين تکون نخورد
# I mean,any more than the 383 miles that it was going to move anyway. منظورم چيزي بيشتر از همون 383مايلي که در حال عادي حرکت ميکنه
# Oh,I've seen that look before. اوه ، من اين نگاه رو قبلا هم ديدم
# This is just going to be two weeks of moping and tedious emo songs and calling me to come down to pet stores to look at cats. از همين آلان دو هفته ، تي کشيدن داريم و اهنگ ها ي ملات اور اِمو و منو صدا ميکنه که بريم به فروشگاه حيوانات و گربه ها رو ببينم
# I don't know if I can take it. نميدونم ميتونم تحمل کنم يانه
# You could power down. خوب ميتوني خاموش بشي
# Well,as usual,wolowitz has the solution. مثل هميشه ، ولويتز يه راه حل داره
# I happen to know a place where there are plenty of eligible women and leonard could have his pick. من بطور اتفاقي يه جايي رو ميشناسم که تعداد بسيار زيادي خانوم هاي واجد شرايط هست که لئونارد ميتونه يکيشون رو انتخاب کنه
# remember the latin hips. رقص باسن لاتين رو درنظر بگيريد
# Shoulders stay still,and... we sway. شونه ها صاف و ميچرخيم
# One,two,three... ... five,six,seven. يک ، دو ، سه پنج ، شش ، هفت...
# I think mrs. Tishman's got her eye on you. به نظر خانوم تيشمان چشمش تورو گرفته
# I've been there. You're in for a treat. من ميدونم شام دعوتي
# oh,yeah... oh,good lord. اه ، خداي مهربون
# God,that's a good song. خداي من ، اين اهنگ خيلي محشره
# If you're compiling a mix cd for a double suicide. داري از يه ميکس سي دي در مورد خودکشي طرفداري ميکني
# Oh,I hope that scratching post is for you. اوه ، اميدوارم اين وسايل براي خودت باشه
# I know what you're thinking. I've taken your asthma into account. ميدونم به چي فکر ميکني من حساب مشکل تنفسي تو رو هم کردم
# There's a feline geneticist in san diego who's developed the cutest little hypoallergenic calicos. يک همايش ژنتيک شناسي گربه ها ، در سانتيگو برگزار ميشه که باحالترين گربه هاي کوچولوي خالخالي که حساسيت ايجاد نميکنه رو ارائه کرده
# Leonard,listen to me... I've been thinking about names. گوش کن من فقط دارم به اسمش فکرميکنم
# I'm kind of torn between einstein,newton and sergeant fuzzy boots. من يه جورايي بين انشتين ، نيوتن و سرجنت فوزي بوتس موندم
# Leonard,do you really think you can satisfy your need for a relationshh witip a genetically altered cat? تو واقعا فکر ميکني نيازت برطرف ميشه اونم با رابطه برقرار کردن با يه گربه ژنتيکي؟
# If it's a cute,little,cuddly cat. اگه اون يه گربه کوچولو ،باحال وملوس باشه
# Oh,come on. اوه ، بيخيال لئونارد
# Leonard... this is obviously about penny. مسلما ناراحتيد به خاطر پنيه
# It doesn't matter. اصلا مهم نيست
# The woman's not interested in me. The woman rejected me. زنها به من علاقه اي ندارند اين زن منو رد کرد
# Okay,look,I think that you have as much of a chance of having a sexual relationship with penny as the hubble telescope does of discovering at the center of every black hole is a little man with a flashlight searching for a circuit breaker. ببين من فکرميکنم شانس تو براي برقراري يه رابطه جنسي با پني مثل شانس
# Nevertheless, بهرحال
# I do feel obligated to point out to you that she did not reject you. من خودم رو ملزم ميدونم که به جنابعالي متذکر بشم که پني تورو رد نکرده
# You did not ask her out. تو اصلا از اون درخواست نکردي
# I didn't ask her out. I should ask her out. من ازش تقاضا نکردم بايد ازش تقاضا ميکردم
# No,no,now that was not my point. نه ، نه نميخواستم اينو بگم
# My point was don't buy a cat. ميخواستم بگم که يه گربه نخري
# No,but you're right. نه ، ولي حق با توئه
# I should march over there and ask her out. من بايد آلان برم اونجا و ازش درخواست کنم
# Oh,goody,we're getting a cat. واي مامان گربه رو خريديم
# Good afternoon,penny. So,hi... hey. عصر بخير ، پني سلام
# I was wondering if you had plans for dinner. ميخواستم ببينم براي شام برنامه اي داري
# Uh,you mean dinner tonight? منظورت شام امشبه؟
# There is an inherent ambiguity in the word "dinner. در لغت شام يه جور ايهام معنايي وجود داره
# " Technically it refers to the largest meal of the day whenever it's consumed. از نظر تکنيکي اين لغت به بزرگترين وعده قضايي روز گفته ميشه حالا هر وقت که خورده بشه
# So to clarify here,by dinner I mean supper. پس براي واضح تر شدن موضوع منظورم شام عارفانست
# Supper? شام عارفانه يا شام
# Or dinner. I was thinking 6:30 if you can go. فکرميکنم 6:
# Or a different time. 30 خوبه اگه بتوني بياي ويا يه وقته ديگه
# Uh,6:30's great. 6: 30عاليه
# Great. Yeah,I like hanging out with you guys. عالي شد من دوست دارم با شما بچه ها بيرون برم
# Us guys? ما بچه ها؟
# Yeah,you know,sheldon,howard,raj. Who all's coming? بله ، ميدوني شلدون ، هاوارد ، راج هرکي که بياد
# They... might all be there. اونا ممکنه همه باشن
# Or a subset of them might be there. ويا فقط چندتاشون باشن
# Algebraically speaking,there are too many unknowns. اگه به بيان جبري بخوام بگم مجهولاي زيادي وجود داره
# For example,sheldon had quiznos for lunch. براي مثال شلدون براي نهار فست فود کويزون خورده
# Sometimes he finds that filling,other times he doesn'T. بعضي وقتها باد ميکنه البته هميشه اينجور نميشه
# It's no fault of quiznos- اشکال از فست فود کويزون نيست اونا منوهاي مختلفي دارن
# they have a varied menu. Okay,whatever. It sounds like fun. باشه ، بهرحال فکرکنم خوش بگذره
# Did we say a time? خوب چه ساعتي شد؟
# 6:30. 6: 30
# And that's still good for you? هنوزم روحرفت هستي
# It's fine. 'Cause it's not carved in stone. اره خوبه چون روي سنگ که هک نکرديم نه ، 6:
# No,6:30's great. 30 خوبه
# I'll get my chisel. من برم قلم سنگ تراشيم رو بيارم
# To... carve the... براي ... هکاکي ولش کن 6:
# I'll see you at 6:30. 30 ميبينمت
# How do I look? به نظرت چطورم؟
# Could you be more specific? نميتوني يکم جذاب تر باشي
# Can you tell I'm perspiring a little? به نظرت من يکم عرق نکردم؟
# No. The dark crescent shaped patterns under your arms conceal it nicely. نه ، اون حلال هاي تيره رنگي که زيربقلت شکل گرفته رو خيلي خوب پنهان کردي
# What time is your date? 6:30. قرارتون ساعت چنده؟
# Perfect. 30 عاليه .
# That gives you two hours and 15 minutes for that dense molecular cloud of aramis to dissipate. يعني تو دو ساعت و ربع وقت داري از اين حالت انقباض عضلاني خارج بشي
# Is it too much? بنظرت زياده؟
# Not if you're a rugby team. براي يه تيم راگبي نه
# By the way,if it should ever come up,you didn't join us because you stuffed yourself with a chicken carbonara sub at quiznos. اگه قرارمون جور شد تو با ما نيا چون تو درگير يه چربي مرغي که از خوردن فست فود بوده
# Why would I join you? چرا من بايد باهتون بيام؟
# No reason. همينطوري
# Oh,you know what,maybe this isn't such a good idea. ميدوني چيه شايد اين يه فکر خوب نباشه
# Oh,no,well,now there's always the possibility that alcohol and poor judgment on her part might lead to a nice romantic evening. نه ، خوب بهرحال هميشه اين امکان وجود داره که مصرف الکل و عدم قضاوت صحيح از طرف اون منجر به يه عصر رمانتيک بشه
# You're right. Alcohol,poor judgment- حق باتوئه ، الکل ، قضاوت ضعيف فکر کنم خوب پيش بره
# it could go well. Of course there is the other possibility, that this date kicks off a rather unpleasant six months of the two of you passing awkwardly in the hall, until one of you breaks down and moves to another zip code. اين احتمال هم وجود داره که اين قرار شما شروع يه دوره شش ماهه ناخوشايندتر باشه که از روي خامي و بي تجربگي باهم برخورد کنيد
# You could've stopped at "it could go well. ميتونستي روي همون جمله ي اوضاع خوب پيش ميره توقف کني
# " If I could've,I would've. اگه ميتونستم اينکارو ميکردم
# I mean,I'm a perfectly nice guy. منظورم اينکه من خيلي آدم خوبيم
# There's no reason we couldn't go to the restaurant,and have a lovely dinner, maybe take a walk afterwards,talk about things we have in common. دليلي وجود نداره که ما نريم ويه شام عشقولانه نخوريم و بعدش يه قدمي بزنيم درمورد مسائل مشترکمون صحبت کنيم
# You love pottery? تو شعر دوست داري؟
# I love pottery! من عاشق شعرم
# There's a pause,we both know what's happening. همه چيز از حرکت مي ايسته هردومون ميدونيم چه ميشه خم ميشم و همديگه رو ميبوسيم
# It's a little tentative at first,but then I realize she's kissing me back. اولش بصورت امتحاني ولي بعد مزشو ميفهم
# She's biting my lower lip! اون هم منو ميبوسه ولب پاييني منو گاز ميگيره
# She wants me! This thing is going the distance! اون منو ميخواد اينطوري ميشه و
# We're going to have sex! Oh,god,oh,my god! ما با هم سکس ميکنيم اوه خداي من ، خداي من
# Is the sex starting now? همين الان داري سکس ميکني؟
# I'm having a panic attack. من دچار يه حمله عصبي شدم
# Uh,well then... calm down. اهان ، خوب پس آروم باش
# If I could calm down,I wobe having a panic att... that's why they call it a panic attack. اگه ميتونستم که عصبي نميشدم براي همين اينرو ميگن يه حمله عصبي
# All right,all right. Uh,s- s- sit down. بشين
# Yeah,sit down. آره ، بشين.
# Now close your eyes. حالا چشماتو ببند
# Why? براي چي؟
# Just do it. Okay. تو چشماتو ببند
# Now try to increase your alpha wave activity. حالا سعي کن فعاليت موج آلفا رو افزايش بدي
# What? چي! ؟
# ! It's a biofeedback technique. اين يه نوع تکنيک پسخورد زيستي در روانشناسيه
# It's relaxation through brain wave manipulation. اين يه جور آرامش پيدا کردن از طريق دستکاري امواج مغزه
# I read a paper about it in journal of american neuroscience. من يه مقاله در اين مورد خوندم در مجله علوم عصبي امريکا
# It was a little sparsely sourced,but I think the basic science is valid. منابع اين مقاله خيلي موثق نبود ولي فکر کنم اصل داستان واقعييه
# I probably have it here somewher E. اون مقاله رو يه جا هميجاها گذاشتم
# Who am I kidding? من دارم باخودم شوخي ميکنم؟
# I can't go through with this. من نميتونم اينکارو انجام بدم
# You need to call her and cancel. بايد بهش زنگ بزني و کنسلش کني
# Yes. آره ديگه
# What should I tell her? چي بايد بهش بگم؟
# I don't know. نميدونم ، بهش بگو که من مريضم
# Tell her I'm sick. Not the kind of illness that will make her want to come over and take care of me, but nothing so critical that she'll feel uncomfortable going out with me in the future if I want to try this again. نه اون قدر مريض که مجبور شه بياد عيادت من نه اونقدر بحراني که اگه يه روزي در آينده خواستم دوباره قرار بزارم احساس ناراحتي نداشته باشه و باهام بياد بيرون
# Got it. So I'm assuming nothing venereal? گرفتم پس يعني بيماريت مقاربتي نباشه
# I'll just tell her that you had a routine conoloscopy and haven't quite bounced back. پس فقط بهش ميگم تو يه کلونسکپي داشتي و هنوز از اين آزمايش برنگشتي
# Give me the phone. I thought you wanted to cancel. تلفن رو بده ببينم فکرکردم ميخواي کنسلش کني
# I can't,because if I don't show up she'll still be expecting you. نميتونم چون اگه خودمو نشون ندم منتظر تو ميشه
# Why would she be expecting me? چرا بايد منتظر من باشه؟
# Stop asking me all these questions. اينقدر سئوال نپرس
# I need to take another shower. بايد برم يه دوش ديگه بگيرم
# So are the rest of the guys meeting us here? خوب پس بقيه بچه ها ميان اينجا همو ببينيم
# Oh,yeah... no. اه ، اره ... نه
# It turns out that raj and howard had to work,and sheldon... had a colonoscopy and he hasn't quite bounced back yet. راج و هاوارد کار براشون پيش اومد و شلدون هم ازمايش کلونسکپي داشت و هنوز هم درگير بود
# Oh,my uncle just had a colonoscopy. عموي من هم کلونسکپي داشت
# You're kidding. شوخي ميکني
# Then that's something we have in common. پس من و تو يه نقطه مشترک داريم
# We both have people in our lives who... want to nip intestinal polyps in the bud. ما هردومون افرادي در زندگيمون داريم که ميخواند مانع رشد و پيشروي کرم روده بشند
# so what's new in the world of physics? خوب از دنياي فيزيک چه خبر
# Really? Nothing? واقعا هيچي؟
# Well,with the exception of string theory, not much has happened since the 1930s. البته به جز تئوري استرينگ از سال 1930 تا به حال هيچ نظريه خاصي داده نشده
# And you can't prove string theory. و نميتوني تئوري استرينگ رو ثابت کني
# At best you can say,"hey,look, my idea has an internal logical consistency. به بيان بهتر هي ببين نظريه من يه سازگاري و استحکام منطقي داره
# Well,I'm sure things will pick up. خوب ، من مطمئنم که اوضاع جور ميشه
# What's new at the cheesecake factory? چه خبر از کارخانه کيک پنير؟
# Oh,uh,not much. خير خاصي نيست
# We do have a chocolate key lime that's moving pretty well. ما يه خط توليد شکلات ليمويي دارم که خوب پيش ميره
# What about your,uh... hallway friend? چه خبر از دوسته داخل راهروئت؟
# Doug? داگ؟
# Oh,yeah,I don't know. اره ، نميدونم
# I mean,you know,he's nice and funny,but... can I get you started with some drinks? منظورم اينکه ميدوني اون خيلي مهربون و بامزست ولي
# No! ميخواين با نوشيدني شروع کنيد نه ، اين نه
# You were saying? But... داشتي ميگفتي ولي من يه نوشيدني ميخوام
# I'd like a drink. Just say the "but" thing about doug and then I'll get her back. اون اما رو درمورد داگ ادامه بده من بهش ميگم برگرده
# Okay,well,I don't know,it's just me. نميدونم مشکل خودمم
# I'm still getting over this breakup with kurt and this thing with doug would stju be rebound sex. من هنوز درگير جدايي از کُرت هستم و اين قضيه با داگ فقط يه واکنش جنسيه
# Oh,don't get me started on rebound sex. زبون منو درمورد واکنش جنسي بازنکن
# It's just... it's my pattern. کار من همين شده
# I break up,then I find some cute guy, and then it's just 36 meaningless hours of... you know. من با يکي ميزنم به هم بعدش يه پسر باحال پيدا ميکنم و بعد يه 36 ساعته بي مصرف ميدوني که
# I'm not sure that I do. مطمئن نيستم بدونم
# is that one 36-hour experience, or is that 36 hours spread out over,say... one glorious summer? ايا اين يه تجربه 36 ساعتست يا مثلا ... 36ساعته خيلي خوب
# No,it's usually over a weekend, and trust me,you do not feel good after it. نه معمولا در يه پايان هفتست و باور کن وقتي تموم ميشه هيچ حس خوبي نداريم
# Well,chafing,right? خوب ، خارش بدن ، درسته؟
# Emotionally. از نظر احساسات
# Of course,yeah,emotional chafing. البته ، خارش احساسات يا تحريک ناخوشايند احساسات
# Hey,do you want to see something cool? ميخواي يه چيز خيلي جالب بهت نشون بدم؟
# I can make this olive go into this glass without touching it. من ميتونم اين زيتون رو بکنمش تو اين ليوان بدون اينکه بهش دست بزنم
# Physics. فيزيک
# Wow,centrifugal force. نيروي گريز از مرکز
# Actually,it's centripetal force, which is an inward force generated by the glass acting on the olive... در اصل اين يه نيروي مرکزگراست که يه نيروي بطرف داخله که توسط ليوان ايجاد ميشه ...بر روي زيتون عمل ميکنه
# Yeah,I'm okay. چي شد حالت خوبه؟ آره خوبم
# Did you spill ketchup? سس گوجه فرنگي ريختي پايين؟
# No. نه من خوب نيستم
# I'm not okay. Are you sure you don't want to go to the emergency room? مطمئني نميخواي بري ارژانس
# But I get car sick,too,so... okay. نه ، حالم خوبه خونريزي بند اومده
# I know,but you did throw up. Isn't that a sign of a concussion? Yes. ميدونم ولي تو استفراغ کردي ايا اين نشونه ضربه مغزي نيست
# Sorry about your car,by the way. بخاطر ماشينت متاسفم
# Oh,no,it's fine. You got most of it out the window. اشکالي نداره تقريبا خيلي شو ريختي بيرون پنجره
# The poor guy on the bike. بدبخت اون دوچرخه سواره
# Well,I had a nice time. خيلي خوش گذشت
# Yeah,me,too. به منم همينطور
# Well,um,good night. خوب ، شب بخير
# Was this supposed to be a date? ايا اين يه قرار عشقولانه بود
# No,of course not. البته که نه فقط من و تو
# This was just you and me hanging out with a bunch of guys who didn't show up 'cause of work and a colonoscopy. با يه دسته از بچه ها که کار براشون پيش اومد وکلونسکپي داشتند وپيداشون نشد رفتيم بيرون
# Okay,I was just checking. باشه ، براي اطمينان پرسيدم
# When I take a girl on a date- - and I do- اگه يه روز با يه دختر قراربزارم
# she knows she's been dated.
# Capital D. به وضوح ميفهمه
# boldface. Undeinrled. Da... ted. با خط درشت وزيرش خط کشيده شده قر...
# I think I might have a little concussion. فکرکنم يه کم ضربه مغزي شدم
# So,how was your date? خوب ، قرارت چطور بود؟
# Awesome! ! وحشتناک
# Score one for liquor and poor judgment. نمره مشروب خوروندن و قضاوت ناصحيح مساوي يک
# You know, I've been thinking about timetravel again. ميدوني من داشتم به سفر زمان فکرميکردم
# Did you hit a roadblock with invisibility? نکنه در اثر کمبود ديد با يه مانع تو خيابان برخورد کردي؟
# Put it on a backburner. يکي طلبد
# Anyway. It occurs to me, بهرحال تو اين فکرم که
# If I have ever did perfect time machine, اگر يه وقت تونستم يه ماشين زمان داشته باشم
# I'd just go into the past and give it to myself. برميگردم به گذشته و اون ماشين رو تحويل خودم ميدم
# That's eliminating the need for me to invent it in the first place. و به اين ترتيب ديگه لازم نيست براي اختراعش زحمت بکشم
# Yeah, it really kicks the pressure off. بله ، اين کار واقعا فشار تحقيقات رو کم ميکنه
# Sounds like a breakthrough. آره ،از پيش پا برداشتن موانع
# Should I call Science Magazine and tell them to hold the cover? ميخواي زنگ بزنم به يه مجله علمي و صفحه اول رو رزرو کنم
# It's time travel, I will have already done that. اين يه سفر زمانه من قبلا اينکارو کرده ام
# Then I guess congratulations are in order. پس فکر کنم تبريکات زيادي در راهه
# No, congratulations will have been in order. نه ، تبريکات در راه بوده اند تا زمانش برسه
# You know, I am not going to enjoy this party. ميدوني اين پارتي به من حال نميده
# I know, I'm familiar with you. ميدونم ميشناسمت
# The last department party, Professor Finkleday cornered me and talked about spelunking for 45 minutes. تو آخرين پارتي دانشکده پروفسور فينک لدي منو کشيد کنار و 45 دقيقه درمورد غارشناسي با من صحبت کرد
# Yes, I was there. بله ، من اونجا بودم
# You know what's interesting about caves? ميدوني در مورد غارها چي خيلي جالبه ؟
# What? نه ؟
# Then we'll avoid him, we'll meet the new department head, congratulate him, shake his hand and go. خوب پس اونو بيخيال ميشيم و رئيس جديد دانشکده رو ميبينيم باهاش دست ميديم و ميريم
# How's this? اين چطوره ؟
# "Pleased to meet you, Dr. Gablehauser. از ديدن شما خوشحالم دکتر گيبل هازر؟
# "How fortunate for you that the university's چقدر شما خوشانسيد که اين دانشگاه
# "chosen to hire you, despite the fact شما رو براي استخدام انتخاب کرده با وجود اينکه
# "that you've done no original research in 25 years, طي 25 سال گذشته هيچ تحقيقه اصولي انجام نداديد
# "and instead have written a series of popular books و بجاي اون يه سري کتاب هاي عمومي نوشتيد
# "that reduce the great concepts of science و اين کار شما باعث تنزيل مطالب علمي
# "to a series of anecdotes, درقصه هاي کوتاه منجر شد
# "each one dumbed down to accommodate the duration قصه هاي که هرکدوم درحدي خلاصه شده بود که
# "of an average bowel movement. ميانگين زمان يه دستشويي رفتن باشه
# Mahalo." ماهالو
# "Mahalo's" a nice touch. ماهالو دستاورد خوبيه
# You know there only eight consonants in Hawaiian language? ميدوني در زبان هاوايي فقط 8 حرف بدون صدا وجود داره
# Interesting. You should lead with that. جالبه تو بايد در اين زمينه سرمشق باشي
# Oh, God, look at this buffet. اه , خدايا ,بوفه رو حال کن
# I love America. من عاشق آمريکام
# You don't have buffets in India? شما در هند چنيين بوفه هايي نداريد
# Of course, but it's all Indian food. البته که داريم اما اينا همش غذاي هنديه
# You can't find a bagel in Mumbai to save your life. اما تو بمبئي نميتوني يه تيکه نون شيرمال پيدا کني تا حداقل از گشنگي نميري
# Shmear me. بمال روش
# Here's an interesting turn of events. اينجا اتفاقات جديدي داره ميفته؟
# Howard brought a date? هاوارد يه دوست دختر آورده
# A more plausible explanation is that his work in robotics has made an amazing leap forward. يک توضيح قابل قبول اينکه کارش در زمينه روباتيک منجر به يه جهش خارق العاده شده
# Hey, what up, science bitches? هي سلام، چه خبر دانشگندها؟
# May I introduce my special lady friend Summer? اجازه بديد دوست دختر مخصوص خودم ، سامر رو به شما معرفي کنم
# I told you touching's extra. بهت گفته بودم که دست بزني خرجت بيشتر ميشه اهان ، ببخشيد
# Right. Here comes our new boss. بچه ها رئيس جديدمون مودب باشيد
# Be polite. Hi, fellas. Eric Gablehauser. سلام ، اقايون اريک گيبل هازر
# Howard Wolowitz. هاوارد ولدويدز
# Nice to meet you. هاوارد خوشبختم و شما؟
# An actual real scientist. يه دانشمند واقعي و درست
# I can't believe he fired me. باورم نميشه که منو اخراج کرد
# Well, you did call him a glorified high school science teacher whose last successful experiment was lighting his own farts. خوب تو اونو يه معلم علوم دبيرستاني خوندي که يه کمي پيشرفت کرده و آخرين تجربه موفقيت آميزش آتيش زدنه گوزش بوده
# In my defense, براي دفاع از خودم
# I prefaced that by saying, "With all due respect." بايد بگم که من اول يه بلانسبت گفتم
# You're making eggs for breakfast? داري براي صبحانه تخم مرغ درست ميکني؟
# This isn't breakfast, it's an experiment. اين صبحونه نيست اين يه آزمايش علميه
# 'Cause it looks a lot like breakfast. آخه خيلي شبيه صبحونست
# I finally have time to test my hypothesis about the separation of the water molecules from the egg proteins and its impact vis-a-vis taste. بالاخره من فرصت پيدا کردم که فرضيه هاي خودم رو درمورد جدا شدنه ملکولهاي آب از پروتوئين تخم مرغ و همچنين تاثير متقابل اونها آزمايش کنم
# Sounds yummy. به نظر خوشمزه ست
# I look forward to your work with bacon. اميدوارم با گوشت خوک هم امتحان کني
# As do I. منم همين طور
# You know, I'm sure if you just apologize to Gablehauser, he would give you your job back. من مطمئنم که اگه تو از اقاي گيبل هازر عذرخواهي بکني ، کارت رو بهت برميگردونه
# I don't want my job back. من نميخوام برگردم سرکارم
# I've spent the past three and a half years staring at grease boards full of equations. من سه سال ونيم گذشته رو پاي تابلوهاي پر از معادله تلف کردم
# Before that, I spent four years working on my thesis. قبل از اون چهار سال روي تز دکتري کار ميکردم
# Before that, I was in college, and before that, I was in the fifth grade. قبل از اون در دانشگاه بودم و قبل از اون هم در کلاس پنجم بودم
# This is my first day off in decades and I'm going to savor it. اين اولين روز تعطيل من در اين ده ساله و ميخوام حال کنم
# I'll let you get back to fixing your eggs. همون تخم مرغت رو درست کن
# Not just fixing my eggs, I'm fixing everyone's eggs. من فقط تخم مرغه اي خودم رو درست نميکنم من تخم مرغ هاي همه رو درست ميکنم
# And we all thank you. و ما همه از تو تشکر ميکنيم
# Use new eggs. از تخم مرغ تازه استفاده شود
# I'm running out to the market. You need anything? من دارم ميرم خريد شما چيزي نميخوايند؟
# This would be one of those circumstances that people unfamiliar with the law of large numbers would call a coincidence. اين يکي ازاون موقعيت هايي که افرادي که به قوائد بين اعداد بزرگ اشنا نيستند بهش ميگن اتفاق
# I need eggs. من تخم مرغ لازم دارم؟
# Four dozen should suffice. چهار بسته  کافيه
# Four dozen? چهار بسته؟
# Yes, and evenly distributed amongst brown, white, free-range, large, extra large and jumbo. بله و بين اونها به تعداد مساوي از رنگهاي قهواي ، سفيد سايز ، آزاد ، بزرگ ، خيلي بزرگ و غول پيکر باشه
# Okay, one more time. باشه يه دفعه ديگه ميگم
# Never mind. You won't get it right. مهم نيست تو متوجه نخواهي شد
# I'd better come with you. بهتر باهات بيام
# How come you didn't go into work today? خوب ، چي شد که امروز نرفتي سرکار
# I'm taking a sabbatical because I won't kowtow to mediocre minds. مرخصي گرفتم براي اينکه نميخواستم به يه آدم با عقل متوسط تعظيم کنم
# So you got canned, huh? پس افتادي تو قوطي ؟
# Theoretical physicists do not get canned... but yeah. از نظر فيزيک تئوري تو قوطي نيوفتادم ولي آره
# Maybe it's all for the best. شايد يه حکمتي توش باشه
# I always say when one door closes, another one opens. من هميشه ميگم وقتي يه دري بسته ميشه يه در ديگه باز ميشه
# No, it doesn't. نه اينطوري نيست
# Not unless the two doors are connected by relays مگه اينکه دو تا در توسط يه رله با هم ارتباط داشته باشن
# or there are motion sensors involved. يا سنسورهاي حرکتي در کار باشند نه منظور اينکه
# No, I meant... Or if the first door closing creates a change of air pressure that acts upon the second door. يا بسته شدن در اول تغيير در فشار ايجاد کنه که روي در دوم تاثير بزاره
# Slow down. يواش
# Please, slow down! لطفا يواش تند نميريم
# We're fine! You're not leaving yourself enough space between cars. فاصله ات با ماشين جلويي داره کم ميشه
# Oh, sure, I am. نه بابا چي ميگي نه بزار برات حساب کنم
# No, let me do the math for you. This car weighs, let's say 4,000 pounds. فرض کنيم وزن ماشين 4000 پوند باشه
# Now add 140 for me, 120 for you... 120? 140پوند براي من 120 تا براي تو اضافه ميکنيم بهش 120؟
# I'm sorry. Did I insult you? اه ، ببخشيد به شما توهين کردم ؟
# Is your body mass somehow tied into your self-worth? ايا وزن تو يه جورايي روي اعتماد به نفست تاثير داره
# Well, yeah. خوب ، آره
# Anyway, that gives us a total weight of, let's say 4,400 pounds. بهرحال ، با اين حساب وزن کل ميشه فرض کنيم 4400 پوند
# Let's say 4,390. فرض کنيم 4390
# Fine. خوب ، ما داريم به طرف جلو با سرعت
# We're traveling forward at-- good Lord-- 51 miles an hour. اوه خداي مهربون 82 کيلومتر در ساعت حرکت ميکنيم
# Let's assume that your brakes are new and the calipers are aligned. فرض ميکنيم ترمز هاي ماشين نو  باشن وديسک و صفحه هم تنظيم باشن
# Still, by the time we come to a stop, we'll be occupying the same space as that Buick in front of us, an impossibility that nature will quickly resolve into death, mutilation... با اين حساب قبل از اينکه بتونيم متوقف بشيم دقيقا جايي هستيم که بيوک جلويي هست عدم امکان اينکه طبيعت به سرعت تصميم بر
# Oh, look, they built a new putt-putt course. اوه ، ببين دارن يه زمين گلف کوچيک ميسازن
# This is great. به به
# Look at me. منو باش
# I'm in the real world of ordinary people just living their ordinary, colorless workaday lives. من تو دنياي واقعي مردم عاديم که فقط دارن زندگي عادي و بي روحه روزانشون رو انجام ميدن
# No, thankyou. نه دست تو درد نکنه
# And thank you, ordinary person. و دست شما هم درد نکنه آدماي عادي
# You want to hear an interesting thing about tomatoes? ميخواي يه چيز جالب درمورد گوجه بشنوي؟
# No, not really. نه ، خداوکيلي بيخيال
# Listen, didn't you say you need some eggs? گوش کن ، مگه تو نگفتي تخم مرغ لازم داري
# Yes, but anyone who knows anything about the dynamics of bacterial growth knows to pick up their refrigerated food on the way out of the supermarket. چرا ، اما هر شخصي که کمي درمورد پويايي رشد باکتري ها اطلاعات داشته باشه ميدونه که بايد غذاهاي فاسد شدنيش رو از قسمت خروجي سوپر مارکت تهيه کنه
# Okay, then maybe you should start heading on out then. خوب ، پس شايد بهتر باشه بري اون طرف
# No, this is fun. نه ، اينجا سرگرم کنندست خوبه
# Oh, the thing about tomatoes-- and I think you'll really enjoy this-- is they're shelved with the vegetables, but they're technically a fruit. اوه ، درمورد گوجه ميگفتم که فکرکنم خيلي ازش خوشت بياد اينکه اونا توي دسته سبزيجات طبقه بندي ميشن درصورتي که از نظر فني ميوه هستن
# Interesting. جالبه اينطور نيست؟
# Isn't it? No, I mean what you find enjoyable. نه ، منظورم اينکه تو چي رو لذت بخش ميدوني
# Well, there's some value to taking a multivitamin, but the human body can only absorb so much. خوب ، خوردن مولتي ويتامين خيلي خوبه اما بدن انسان فقط تا يه حديشو جذب ميکنه
# What you're buying here are the ingredients for very expensive urine. چيزي که تو الان داري اينجا ميخري محتويات يه ادرار خيلي گرون قيمته
# Well, maybe that's what I was going for. خوب ، ممکنه اين همون چيزي باشه که من ميخوام
# Then you'll want some manganese. پس شايد يکم منگنز لازم داري
# That was fun. خيلي حال داد
# Maybe tomorrow we can go to one of those big warehouse stores. شايد فردا بتونيم با هم بريم تو يه فروشگاه عمده فروشي
# Oh, I don't know. اه من نميدونم شلدون
# It's going to take me a while to recover from all the fun I had today. يکمي طول ميکشه تا من اينهمه حالي که امروز کردم رو حضم کنم
# There are a lot of advantages to buying in bulk. خريد عمده خيلي به صرفه است
# For example, I noticed that you purchase your tampons one-month supply at a time. براي مثال ، دقت کردم که تو نوار بهداشتي هاي يک ماهت رو يه جا ميخري
# Think about it. بهش فکرکن اين يه محصوليه که فاصد نميشه
# It's a product that doesn't spoil and you're going to be needing them for at least the next 30 years. و چيزيه که تو حداقل تا 30 سال آينده بهش نياز داري
# You want me to buy 30 years worth of tampons? تو داري ميگي براي 30 سال نوار بهداشتي بخرم؟
# Well, 30, 35. When did your mother go into menopause? خوب ، 30 ، 35 مادر تو کي به يائسگي رسيد
# I'm not talking about this with you. من در اين مورد با تو حرف نميزنم
# This is a natural human process, and we're talking about statistically significant savings. اين يه فرايند طبيعيه و در ضمن ما داريم درمورد يه صرفه جويي درست وحسابي از طريق آمار صحبت ميکنيم
# Now, if you assume 15 tampons per cycle and a 28-day cycle... خوب حالا فرض کن که 15 نوار براي هردوره پريودد که 28 روز طول بکشه ميخواي
# Are you fairly regular? راستي دوره پريودد منظمه؟
# Okay, no warehouse store, but we're still on for putt-putt golf, right? باشه ، نميرم به فروشگاه عمده فروشي ولي زمين گلف که ميريم درسته؟
# Hey, I just ran into Penny. She seemed upset about something. هي ، من همين الان پني رو ديدم به نظرم از يه چيزي ناراحت بود
# I think it's her time of the month. فکر کنم روز پريود اين ماهش بود
# I marked the calendar for future reference. من توي تقويم علامت زدم که بدونيم چه موقع بوده
# What's with the fish? با ماهي ها چيکار ميکني؟
# It's an experiment. اين يه آزمايشه
# What happened to your scrambled egg research? تحقيقت درمورد تخم مرغ نيمرو به کجا رسيد؟
# Oh, that was a dead end. اه ، اون به بن بست رسيد
# Scrambled eggs are as good as they're ever going to be. تخم مرغ نيمرو به همون خوبييه که هميشه بوده
# So... fish? پس ... ماهي؟
# I read an article about Japanese scientists who inserted DNA from luminous jellyfish into other animals, and I thought, "Hey, fish nightlights." من يه مقاله درمورد دانشمندان زاپني خوندم که که دي ان اي ستاره دريايي نوراني رو به حيوان هاي ديگه وارد کردن و من فکرميکنم هي پسر!
# Fish nightlights? روشنايي توسط ماهي؟
# It's a billion-dollar idea. اين يه نظريه ميليارد دلاريه به کسي نگيا
# Mum's the word. به هيشگي نميگم
# Are you sure you don't want to just apologize to Gablehauser and get your job back? مطمئني که نميخواي بري فقط يه عذرخواهي از گيبل هازر بکني و برگردي سرکارت؟
# No, I have too much to do. نه ، من خيلي کار دارم
# Like luminous fish. مثل ماهي هاي نوراني
# I'm sorry. ببخشيد ...من
# That's just the beginning. اين تازه شروع کاره
# I also have an idea for a bulk mail-order feminine hygiene company. من يه ايده اي هم درمورد شرکت توليدي لوازم بهداشتي زنانه دارم
# Oh, glow-in-the-dark tampons! اوه ، نوارهاي بهداشتي اميد بخش نوراني
# Leonard, we're gonna be rich. لئونارد ما پولدار ميشيم
# Thanks for coming on such short notice. ممنونم که تو اين فرصت کم تشريف آوردي
# You did the right thing calling. کار خوبي کردي که زنگ زدي کار ديگه اي به ذهنم نميرسيد
# I didn't know what else to do. He's lost all focus. Every day he's got a new obsession. اون کلا تمرکزش رو از دست داده هر روز يه وسواس فکري جديد داره
# This is a particularly disturbing one. اين ديگه يکي از اون ايده هاي واقعا آزاردهندست
# Mommy? مامي؟
# Hi, baby! سلام ، عزيزم
# Oh, you got yourself a loom? How nice! Thank you. اوه ، چقدر جالب تو برا خودت يه کارگاه بافندگي درست کردي
# Honey, why'd you get a loom? ممنون عزيزم ، چرا کارگاه درست کردي؟
# I was working with luminous fish, and I thought... من داشتم روي ماهي هاي نوراني کار ميکردم که يهو به ذهنم رسيد
# "loom." بافندگي (به دليل تلفظ اين دوکلمه شلدون به اين فکر (loom :
# Mom, what are you doing here? رسيده که نوراني مامان ، چرا اومدي اينجا؟
# Leonard called me. لئونارد بهم زنگ زد
# I know, but why? ميدونم ، اما چرا؟
# Because one of the great minds of the 21st century is raising glow-in-the-dark fish and weaving serapes. چون که يه کي از بزرگترين مغزهاي قرن 21 داره ماهي هاي روشنايي بخش رو پرورش ميده و شالگردن هاي پشمي مي بافه
# This is not a serape, this is a poncho. A serape is open at the sides; اين شالگردن نيست اين پتوي بارانيه
# a poncho is closed. This is a poncho. شالگردن از دوطرف بازه ولي يه باراني ، نه
# And neither is a reason to call someone'smother. اين يه بارانيه و هيچکدوم از اينها دليل نميشه که يه نفربه مادرم زنگ بزنه
# When was the last time you left the house? جدي؟ اخرين باري که ازخونه بيرون رفتي کي بوده؟
# I went to the market with Penny. That was three weeks ago. با پني رفتيم خريد تو يه سوپرمارکت
# Well, then buckle up! اون مال سه هفته پيش بوده
# In the next four to eight days she's going to get very crabby. خوب ، پس کمربند ايمنيت رو ببند در4 تا 8 روز آينده اون خيلي خيلي بد خلق خواهد شد
# Sweetheart, your little friend is concerned about you. عزيزم دوستت نگرانته
# Yes, well, I'm not a child-- I'm a grown man, capable of living my life as I see fit. آره ، ولي من ، بچه نيستم بزرگ شدم وميتونم اونطور که دوست دارم زندگي کنم
# And I certainly don't need someone telling on me to my mother! و قطعا نياز ندارم که يه نفر به مادر من زنگ بزنه
# Wait, where are you going? To my room. صبر کن ، داري کجا ميري؟
# And no one's allowed in! تو اتاقم و هيچکس حق نداره بياد تو
# He gets his temper from his daddy. اين اخلاقشو از پدرش ياد گرفته
# He's got my eyes. I see. چشماش به من رفته
# All that science stuff, that comes from Jesus. معلومه تمام اون علومي که توسط عيسي بيان شده
# Sheldon, your mom made dinner. شلدون مادرت شام درست کرده من گشنم نيست
# I'm not hungry!
# Don't trouble yourself. He's stubborn. خودت رو اذيت نکن يه دندست
# He may stay in there till the Rapture. احتمالا اونقدر اون تو ميمونه که از هوش بره
# We so sure that's abadthing? مطمئنيد که خطر نداره
# I tell you, I love the boy to death, but he has been difficult since he fell out of me at the K-Mart. بزار بهت بگم من پسرم رو تا پاي جون دوست دارم اما از وقتي که توي فروشگاه من رو ول کرد خيلي يه دنده شده
# Excuse me for being so bold, but I now see where Sheldon gets his smoldering good looks. ببخشيد جسارت ميکنم ولي من الان ميفهم که شلدون اون نگاه سوزانش رو از کي به ارث برده
# Honey, that ain't gonna work, but you keep tryin'. عزيزم ، اينکارا جواب نميده ولي تو سعيت رو بکن
# I made chicken. من جوجه درست ميکنم
# I hope that isn't one of the animals that you people think is magic. اميدوارم که اين يکي جزء حيوان هاي نباشه که شما هنديا فکرميکنيد جادوئيه

# %% [markdown]
# ## Part2: Generate Alignment Seeds

# %%
from utils.alignment_seeds import *

# %%
results = {}
for i in range(12):
    for j in tqdm(range(30)):
        try:
            (en_subset, zh_subset, tbbt_episode) = fetch_subsets(
                episode=all_transcripts,
                en_subtitle=all_en_subtitles,
                zh_subtitle=all_other_subtitles,
                results=coarse_alignments,
                season_id=i+1,
                episode_id=j+1,
                bias=200
            )
            temp = generate_alignment_seeds(en_subset, tbbt_episode, window_size=6)
            results[(i+1, j+1)] = temp
        except:
            pass
# Out:
# 100%|██████████| 30/30 [00:38<00:00,  1.28s/it]
# 100%|██████████| 30/30 [00:06<00:00,  4.80it/s]
# 100%|██████████| 30/30 [00:05<00:00,  5.48it/s]
# 100%|██████████| 30/30 [00:29<00:00,  1.01it/s]
# 100%|██████████| 30/30 [00:15<00:00,  1.93it/s]
# 100%|██████████| 30/30 [00:35<00:00,  1.18s/it]
# 100%|██████████| 30/30 [00:37<00:00,  1.23s/it]
# 100%|██████████| 30/30 [00:50<00:00,  1.67s/it]
# 100%|██████████| 30/30 [00:30<00:00,  1.03s/it]
# 100%|██████████| 30/30 [00:00<00:00, 566797.84it/s]
# 100%|██████████| 30/30 [00:00<00:00, 197224.33it/s]
# 100%|██████████| 30/30 [00:00<00:00, 587986.54it/s]

# %%
with open(root_path + "0_alignment_seeds.pkl", "wb") as f:
    pkl.dump(results, f)

# %% [markdown]
# ## Part 3: Incrementally Extend from Alignment Seeds

# %%
with open(root_path + "0_alignment_seeds.pkl", "rb") as f:
    alignment_seeds = pkl.load(f)

# %%
# The input to each extension function should be epi2sub

# %%
from utils.alignment_extension import *
from utils.helper_functions import *
from utils.ultimate_alignment import *

# %%
further_alignment = {}
for (i, j) in alignment_seeds.keys():
    (en_subset, zh_subset, tbbt_episode) = fetch_subsets(
                episode=all_transcripts,
                en_subtitle=all_en_subtitles,
                zh_subtitle=all_other_subtitles,
                results=coarse_alignments,
                season_id=i,
                episode_id=j,
                bias=200
            )
    epi2sub = filter_by_idx(turn_sub2epi_into_epi2sub(alignment_seeds[(i,j)]))
    # Extend the neighbor
    while True:
        temp_len = len(turn_sub2epi_into_epi2sub(epi2sub))
        epi2sub = filter_by_idx(add_neighbor_subtitles_to_episode(en_subset, epi2sub, tbbt_episode))
        if temp_len==len(turn_sub2epi_into_epi2sub(epi2sub)):
            break

    # Perform a set of extension
    while True:
        temp_len = len(turn_sub2epi_into_epi2sub(epi2sub))

        gaps, _ = get_subset_in_gaps(epi2sub)
        epi2sub = filter_by_idx(add_strict_match_within_gaps(gaps, epi2sub, en_subset, tbbt_episode))

        gaps, _ = get_subset_in_gaps(epi2sub)
        epi2sub = filter_by_idx(add_wer_match_within_gaps(gaps, epi2sub, en_subset, tbbt_episode))

        gaps, _ = get_subset_in_gaps(epi2sub)
        epi2sub = filter_by_idx(add_wer_substring_match_within_gaps(gaps, epi2sub, en_subset, tbbt_episode))

        epi2sub = filter_by_idx(add_neighbor_subtitles_to_episode(en_subset, epi2sub, tbbt_episode))

        if temp_len==len(turn_sub2epi_into_epi2sub(epi2sub)):
            break

    # Perform alignment within gaps
    while True:
        temp_len = len(turn_sub2epi_into_epi2sub(epi2sub))

        gaps, _ = get_subset_in_gaps(epi2sub)
        epi2sub = filter_by_idx(add_strict_match_within_gaps(gaps, epi2sub, en_subset, tbbt_episode))

        gaps, _ = get_subset_in_gaps(epi2sub)
        epi2sub = filter_by_idx(add_wer_match_within_gaps(gaps, epi2sub, en_subset, tbbt_episode))

        gaps, _ = get_subset_in_gaps(epi2sub)
        epi2sub = filter_by_idx(add_wer_substring_match_within_gaps(gaps, epi2sub, en_subset, tbbt_episode))

        epi2sub = filter_by_idx(extend_neighbors_episode_sliding(en_subset, epi2sub, tbbt_episode))

        if temp_len==len(turn_sub2epi_into_epi2sub(epi2sub)):
            break

    # Extend Subtitle ids with its min and max index
    for x in epi2sub:
        epi2sub[x] = [i for i in range(min(epi2sub[x]), max(epi2sub[x])+1)]

    # Perform ultimate alignment
    gaps = get_final_stage_gap_pairs(epi2sub)
    epi2sub = ultimate_alignment(gaps, epi2sub, en_subset, tbbt_episode)

    further_alignment[(i,j)] = epi2sub

# %%
for item in further_alignment:
    epi2sub = further_alignment[item]
    sub2epi = turn_sub2epi_into_epi2sub(further_alignment[item])
    print(item, "Subtitle:", len(sub2epi), len(sub2epi)/(max(sub2epi)-min(sub2epi)), "||", "Episode:", len(further_alignment[item]),  len(further_alignment[item])/len(all_transcripts[item])*100, min(further_alignment[item].keys()))
    # print(epi2sub)
# Out:
# (1, 1) Subtitle: 355 0.9833795013850416 || Episode: 255 76.34730538922156 0
# (1, 2) Subtitle: 299 0.9933554817275747 || Episode: 197 79.43548387096774 0
# (1, 3) Subtitle: 301 0.9709677419354839 || Episode: 201 77.60617760617761 3
# (1, 4) Subtitle: 288 0.993103448275862 || Episode: 180 75.63025210084034 1
# (1, 5) Subtitle: 277 0.9892857142857143 || Episode: 191 82.32758620689656 0
# (1, 7) Subtitle: 306 0.9745222929936306 || Episode: 232 79.72508591065292 8
# (1, 9) Subtitle: 280 0.99644128113879 || Episode: 188 80.34188034188034 1
# (1, 10) Subtitle: 273 0.9927272727272727 || Episode: 180 76.59574468085107 0
# (1, 11) Subtitle: 291 0.9931740614334471 || Episode: 209 81.32295719844358 4
# (1, 12) Subtitle: 465 1.0021551724137931 || Episode: 113 46.50205761316872 102
# (1, 13) Subtitle: 310 0.9810126582278481 || Episode: 202 76.22641509433963 0
# (1, 14) Subtitle: 306 0.9652996845425867 || Episode: 196 80.65843621399176 0
# (1, 15) Subtitle: 303 0.9837662337662337 || Episode: 200 80.64516129032258 0
# (1, 16) Subtitle: 266 0.9743589743589743 || Episode: 186 75.0 0
# (2, 4) Subtitle: 406 0.9759615384615384 || Episode: 207 76.95167286245353 5
# (2, 6) Subtitle: 284 0.993006993006993 || Episode: 198 80.81632653061224 0
# (3, 21) Subtitle: 351 0.9859550561797753 || Episode: 212 79.1044776119403 6
# (3, 23) Subtitle: 315 0.9968354430379747 || Episode: 216 83.3976833976834 3
# (4, 1) Subtitle: 285 0.9437086092715232 || Episode: 192 74.70817120622569 3
# (4, 3) Subtitle: 350 0.9641873278236914 || Episode: 225 79.50530035335689 1
# (4, 4) Subtitle: 343 0.98 || Episode: 230 84.87084870848709 0
# (4, 5) Subtitle: 318 0.9845201238390093 || Episode: 192 80.67226890756302 0
# (4, 6) Subtitle: 312 0.975 || Episode: 201 75.84905660377359 2
# (4, 8) Subtitle: 306 0.9683544303797469 || Episode: 181 81.16591928251121 0
# (4, 16) Subtitle: 309 0.9903846153846154 || Episode: 190 77.55102040816327 1
# (4, 19) Subtitle: 342 0.9688385269121813 || Episode: 216 81.81818181818183 0
# (4, 21) Subtitle: 274 0.982078853046595 || Episode: 176 81.48148148148148 0
# (4, 22) Subtitle: 346 0.9829545454545454 || Episode: 218 86.5079365079365 0
# (4, 23) Subtitle: 303 0.9901960784313726 || Episode: 210 84.33734939759037 1
# (4, 24) Subtitle: 325 0.9878419452887538 || Episode: 196 80.99173553719008 0
# (5, 2) Subtitle: 278 0.9488054607508533 || Episode: 166 74.77477477477478 1
# (5, 6) Subtitle: 326 0.9908814589665653 || Episode: 184 91.0891089108911 0
# (5, 12) Subtitle: 295 0.9800664451827242 || Episode: 173 88.26530612244898 1
# (5, 14) Subtitle: 289 0.993127147766323 || Episode: 155 83.78378378378379 0
# (5, 15) Subtitle: 327 0.990909090909091 || Episode: 166 82.58706467661692 3
# (5, 20) Subtitle: 344 0.9772727272727273 || Episode: 204 87.55364806866953 0
# (5, 23) Subtitle: 340 0.9912536443148688 || Episode: 182 84.25925925925925 1
# (6, 2) Subtitle: 318 1.0 || Episode: 197 82.42677824267783 0
# (6, 3) Subtitle: 327 0.993920972644377 || Episode: 174 82.85714285714286 2
# (6, 4) Subtitle: 306 0.9902912621359223 || Episode: 194 82.5531914893617 0
# (6, 5) Subtitle: 312 1.0 || Episode: 187 80.60344827586206 0
# (6, 6) Subtitle: 341 0.9884057971014493 || Episode: 172 83.09178743961353 1
# (6, 7) Subtitle: 338 0.9970501474926253 || Episode: 178 89.44723618090453 0
# (6, 8) Subtitle: 307 0.959375 || Episode: 199 81.22448979591836 0
# (6, 9) Subtitle: 321 0.9968944099378882 || Episode: 177 82.71028037383178 2
# (6, 14) Subtitle: 294 0.9932432432432432 || Episode: 175 81.01851851851852 1
# (6, 15) Subtitle: 322 0.9969040247678018 || Episode: 186 76.5432098765432 0
# (6, 16) Subtitle: 288 0.9896907216494846 || Episode: 172 77.82805429864254 0
# (6, 17) Subtitle: 320 1.0031347962382444 || Episode: 83 47.42857142857143 67
# (6, 19) Subtitle: 311 0.9841772151898734 || Episode: 191 81.27659574468085 3
# (6, 20) Subtitle: 269 0.992619926199262 || Episode: 170 77.6255707762557 0
# (6, 21) Subtitle: 298 0.9966555183946488 || Episode: 159 81.95876288659794 0
# (7, 1) Subtitle: 317 0.9577039274924471 || Episode: 172 72.57383966244726 3
# (7, 2) Subtitle: 348 0.9858356940509915 || Episode: 215 82.6923076923077 2
# (7, 6) Subtitle: 357 0.9944289693593314 || Episode: 181 83.41013824884793 3
# (7, 10) Subtitle: 347 0.9971264367816092 || Episode: 192 85.71428571428571 0
# (7, 11) Subtitle: 311 0.9904458598726115 || Episode: 214 84.92063492063492 1
# (7, 15) Subtitle: 316 0.9968454258675079 || Episode: 190 80.50847457627118 0
# (7, 16) Subtitle: 318 0.9875776397515528 || Episode: 215 83.65758754863813 1
# (7, 17) Subtitle: 268 0.9781021897810219 || Episode: 170 75.22123893805309 2
# (7, 18) Subtitle: 325 0.9643916913946587 || Episode: 209 83.6 0
# (7, 19) Subtitle: 309 0.9626168224299065 || Episode: 189 79.74683544303798 0
# (7, 20) Subtitle: 361 0.94750656167979 || Episode: 190 78.51239669421489 0
# (7, 22) Subtitle: 288 0.96 || Episode: 181 79.73568281938326 0
# (7, 23) Subtitle: 310 1.0 || Episode: 203 81.2 4
# (8, 1) Subtitle: 334 0.9681159420289855 || Episode: 183 82.43243243243244 0
# (8, 2) Subtitle: 294 0.98989898989899 || Episode: 185 80.08658008658008 0
# (8, 3) Subtitle: 279 0.9964285714285714 || Episode: 184 84.01826484018264 0
# (8, 6) Subtitle: 345 0.9801136363636364 || Episode: 219 86.22047244094489 1
# (8, 7) Subtitle: 303 0.9869706840390879 || Episode: 194 81.17154811715481 0
# (8, 9) Subtitle: 290 0.9931506849315068 || Episode: 190 79.83193277310924 11
# (8, 11) Subtitle: 299 1.0 || Episode: 192 82.75862068965517 0
# (8, 12) Subtitle: 299 0.9739413680781759 || Episode: 189 83.25991189427313 1
# (8, 14) Subtitle: 353 1.0 || Episode: 204 84.29752066115702 0
# (8, 15) Subtitle: 315 0.9936908517350158 || Episode: 191 77.9591836734694 0
# (8, 16) Subtitle: 315 0.984375 || Episode: 191 82.32758620689656 0
# (8, 17) Subtitle: 293 1.0034246575342465 || Episode: 183 79.22077922077922 0
# (8, 18) Subtitle: 306 0.9839228295819936 || Episode: 202 82.78688524590164 0
# (8, 19) Subtitle: 471 1.0 || Episode: 72 33.17972350230415 119
# (8, 20) Subtitle: 315 0.9936908517350158 || Episode: 207 82.47011952191235 3
# (8, 21) Subtitle: 296 0.976897689768977 || Episode: 195 80.91286307053942 0
# (8, 22) Subtitle: 292 0.9898305084745763 || Episode: 168 76.71232876712328 2
# (8, 23) Subtitle: 268 0.9925925925925926 || Episode: 175 83.33333333333334 0
# (8, 24) Subtitle: 305 0.9870550161812298 || Episode: 214 77.53623188405797 0
# (9, 1) Subtitle: 331 0.9622093023255814 || Episode: 216 80.59701492537313 0
# (9, 3) Subtitle: 328 0.9820359281437125 || Episode: 208 80.93385214007782 1
# (9, 4) Subtitle: 292 0.9798657718120806 || Episode: 167 83.91959798994975 0
# (9, 7) Subtitle: 287 0.9828767123287672 || Episode: 170 80.95238095238095 0
# (9, 8) Subtitle: 289 0.9829931972789115 || Episode: 200 83.33333333333334 1
# (9, 9) Subtitle: 322 0.9907692307692307 || Episode: 202 82.78688524590164 0
# (9, 10) Subtitle: 321 0.9756838905775076 || Episode: 176 81.86046511627907 0
# (9, 11) Subtitle: 269 0.9853479853479854 || Episode: 180 72.0 7
# (9, 12) Subtitle: 310 0.9841269841269841 || Episode: 207 81.17647058823529 0
# (9, 16) Subtitle: 314 0.9781931464174455 || Episode: 183 78.54077253218884 3
# (9, 17) Subtitle: 285 0.986159169550173 || Episode: 162 82.6530612244898 0
# (9, 18) Subtitle: 298 0.9867549668874173 || Episode: 203 84.58333333333333 0

# %%
with open(root_path+'1_alignment_extension.pkl', 'wb') as f:
    pkl.dump(further_alignment, f)

# %% [markdown]
# # Part 4: Add Head Tail

# %%
root_path = "results/tbbt_en_zh/"
with open(root_path + "1_alignment_extension.pkl", "rb") as f:
    alignment_seeds = pkl.load(f)

# %%
def get_optimal_cer_from_episode(ground_truth, hypothesis_pool, utt_ids):
    scores = []
    for i, hypothesis in enumerate(hypothesis_pool):
        scores.append(jiwer.cer(ground_truth, hypothesis))
    return min(scores), hypothesis_pool[scores.index(min(scores))], ground_truth, utt_ids[scores.index(min(scores))]

# %%
def fetch_before_after(en_subset, zh_subset, tbbt_episode, epi2sub):
    gap_pairs = []
    # Fetch the Episode-Subtitle Pair before the episode start
    epi_ids = list(range(0, min(epi2sub.keys())))
    num_epi_token = 0
    for i in epi_ids:
        num_epi_token += len(tbbt_episode[i][0].strip().split(" "))

    sub_ids = [min(epi2sub[min(epi2sub.keys())])]
    num_sub_token = len(en_subset[sub_ids[-1]].strip().split(" "))
    while num_sub_token <= num_epi_token*3:
        sub_ids.append(sub_ids[-1]-1)
        num_sub_token += len(en_subset[sub_ids[-1]].strip().split(" "))
    gap_pairs.append([epi_ids, sorted(sub_ids)])

    # Fetch the Episode-Subtitle Pair after the episode end
    epi_ids = list(range(max(epi2sub.keys())+1, len(tbbt_episode)))
    num_epi_token = 0
    for i in epi_ids:
        num_epi_token += len(tbbt_episode[i][0].strip().split(" "))

    sub_ids = [max(epi2sub[max(epi2sub.keys())])+1]
    num_sub_token = len(en_subset[sub_ids[-1]].strip().split(" "))
    while num_sub_token <= num_epi_token*3:
        sub_ids.append(sub_ids[-1]+1)
        num_sub_token += len(en_subset[sub_ids[-1]].strip().split(" "))
    gap_pairs.append([epi_ids, sub_ids])

    return gap_pairs

# %%
def before_after_wer_match(en_subset, episode, epi_ids, sub_ids):
    # Load Sub2Epi
    temp_sub2epi = {}
    temp_epi2sub = {}
    for sub_id in sub_ids:
        subtitle = transformation(en_subset[sub_id].replace("’", " ").replace('…', " "))
        subtitle_tokens = subtitle.strip().split(" ")
        sub_len = len(subtitle_tokens)
        if sub_len <= 4:
            continue

        utt_segments = []
        utt_ids = []
        for epi_id in epi_ids:
            utt = transformation(episode[epi_id][0].replace("’", " ").replace('…', " "))
            utt_tokens = utt.strip().split(" ")
            for j in range(len(utt_tokens) - sub_len+1):
                utt_segments.append(" ".join(utt_tokens[j: j + sub_len]))
                utt_ids.append(epi_id)
        if utt_segments != [] and subtitle not in [" ", ""]:
            score, hypo, truth, index = get_optimal_cer_from_episode(subtitle, utt_segments, utt_ids)
            if score >= 0.5:
                continue
            # print("**********")
            # print("Score:", score)
            # print("Subtitle:", truth)
            # print("Episode:", hypo)
            # print("Epi ID:", index, "Sub ID:", sub_id)
            temp_sub2epi[sub_id] = [index]
            if index not in temp_epi2sub:
                temp_epi2sub[index] = [sub_id]
            else:
                temp_epi2sub[index].append(sub_id)
    # print("Sub2Epi:", temp_sub2epi)
    # print("Epi2Sub:", temp_epi2sub)
    return temp_sub2epi

# %%
further_alignment = {}
for (i, j) in alignment_seeds.keys():
    print(i, j)
    (en_subset, zh_subset, tbbt_episode) = fetch_subsets(
                episode=all_transcripts,
                en_subtitle=all_en_subtitles,
                zh_subtitle=all_other_subtitles,
                results=coarse_alignments,
                season_id=i,
                episode_id=j,
                bias=200
            )
    epi2sub = filter_by_idx(alignment_seeds[(i,j)])

    head_tail_sub2epi = {}

    gap_pairs = fetch_before_after(en_subset, zh_subset, tbbt_episode, epi2sub)
    for item in gap_pairs:
        temp = before_after_wer_match(en_subset, tbbt_episode, item[0], item[1])
        for x in temp:
            head_tail_sub2epi[x] = temp[x]
    print(head_tail_sub2epi)
    print("=="*50)

    further_alignment[(i,j)] = head_tail_sub2epi
# Out:
# 1 1
# {}
# ====================================================================================================
# 1 3
# {}
# ====================================================================================================
# 1 4
# {}
# ====================================================================================================
# 1 5
# {}
# ====================================================================================================
# 1 6
# {}
# ====================================================================================================
# 1 7
# {180: [0], 182: [1], 183: [3], 520: [280], 521: [280], 522: [281]}
# ====================================================================================================
# 1 9
# {}
# ====================================================================================================
# 1 10
# {}
# ====================================================================================================
# 1 11
# {190: [2], 191: [2]}
# ====================================================================================================
# 1 12
# {-417: [24], -414: [25], -413: [26], -412: [27], -410: [29], -409: [30], -408: [31], -405: [33], -404: [34], -402: [36], -401: [37], -400: [37], -399: [37], -398: [38], -396: [40], -393: [44], -392: [44], -391: [45], -389: [47], -388: [48], -387: [48], -384: [51], -383: [52], -382: [53], -381: [28], -380: [56], -379: [57], -378: [58], -377: [58], -376: [58], -375: [59], -374: [59], -372: [62], -371: [62], -369: [63], -368: [63], -367: [63], -365: [65], -364: [66], -363: [67], -361: [68], -360: [69], -359: [70], -358: [70], -357: [71], -356: [71], -355: [72], -354: [72], -353: [73], -352: [73], -351: [74], -349: [76], -348: [77], -347: [77], -345: [78], -344: [81], -343: [81], -341: [82], -340: [83], -339: [85], -338: [85], -337: [86], -335: [87], -333: [89], -330: [93], -329: [93], -328: [93], -327: [94], -326: [94], -325: [94], -324: [97], -323: [98], -322: [98], -321: [98], -320: [98], -319: [98], -318: [99], -317: [100], -316: [101], -315: [101], -311: [76], -308: [72], -290: [63], -264: [65], -254: [37], -252: [76], -205: [59], -185: [58], -139: [17], -100: [21], -40: [87], -32: [94], -23: [19], 1: [76], 4: [21], 29: [76], 511: [229]}
# ====================================================================================================
# 1 13
# {512: [248], 513: [249], 516: [252], 518: [254]}
# ====================================================================================================
# 1 14
# {}
# ====================================================================================================
# 1 15
# {}
# ====================================================================================================
# 1 16
# {484: [231], 485: [231], 487: [232], 488: [233], 490: [236]}
# ====================================================================================================
# 2 1
# {180: [0], 181: [0], 182: [1]}
# ====================================================================================================
# 2 2
# {199: [1], 511: [244], 513: [245], 514: [247], 515: [247]}
# ====================================================================================================
# 2 3
# {492: [232]}
# ====================================================================================================
# 2 4
# {194: [0], 198: [4], 510: [257]}
# ====================================================================================================
# 2 5
# {}
# ====================================================================================================
# 2 6
# {500: [231], 501: [232]}
# ====================================================================================================
# 2 7
# {179: [0], 193: [14], 488: [258]}
# ====================================================================================================
# 2 9
# {-402: [59], -353: [4], -352: [4], -351: [5], -350: [5], -349: [6], -346: [8], -345: [9], -342: [12], -340: [12], -337: [16], -335: [18], -334: [18], -333: [20], -332: [21], -331: [22], -330: [22], -329: [23], -328: [24], -327: [24], -326: [24], -325: [24], -324: [24], -322: [26], -320: [29], -317: [33], -315: [35], -314: [35], -311: [38], -310: [39], -309: [39], -308: [39], -306: [41], -304: [43], -303: [43], -301: [45], -299: [47], -296: [49], -295: [50], -294: [51], -293: [51], -292: [51], -291: [51], -290: [51], -288: [53], -286: [53], -285: [53], -282: [55], -281: [56], -279: [57], -278: [57], -276: [59], -275: [59], -274: [59], -273: [60], -272: [60], -271: [61], -270: [62], -269: [62], -266: [66], -265: [66], -264: [68], -261: [68], -260: [70], -259: [70], -258: [71], -255: [74], -254: [75], -253: [76], -252: [76], -251: [77], -250: [78], -245: [83], -243: [85], -241: [87], -240: [87], -237: [90], -236: [90], -235: [90], -234: [91], -233: [91], -231: [94], -228: [98], -227: [99], -226: [99], -225: [100], -224: [101], -222: [103], -221: [104], -220: [105], -219: [105], -218: [106], -217: [107], -216: [107], -215: [107], -214: [107], -212: [109], -211: [109], -210: [109], -209: [109], -208: [110], -206: [112], -205: [112], -204: [112], -203: [112], -202: [113], -201: [114], -197: [62], -179: [22], -154: [66], -150: [106], -106: [91], -96: [85], -84: [57], -77: [88], -54: [22], 18: [56], 20: [22], 49: [112], 60: [68], 64: [39]}
# ====================================================================================================
# 2 11
# {463: [216], 464: [217], 466: [218], 468: [219], 469: [220]}
# ====================================================================================================
# 2 12
# {}
# ====================================================================================================
# 2 13
# {}
# ====================================================================================================
# 2 14
# {}
# ====================================================================================================
# 2 15
# {422: [215]}
# ====================================================================================================
# 2 16
# {480: [240], 481: [241], 482: [242]}
# ====================================================================================================
# 2 17
# {}
# ====================================================================================================
# 2 18
# {}
# ====================================================================================================
# 2 19
# {}
# ====================================================================================================
# 2 20
# {}
# ====================================================================================================
# 2 21
# {}
# ====================================================================================================
# 2 22
# {199: [0], 200: [1]}
# ====================================================================================================
# 2 23
# {}
# ====================================================================================================
# 3 1
# {200: [0]}
# ====================================================================================================
# 3 2
# {470: [211], 471: [212]}
# ====================================================================================================
# 3 3
# {195: [0], 475: [231], 477: [233]}
# ====================================================================================================
# 3 4
# {}
# ====================================================================================================
# 3 5
# {488: [228], 489: [228]}
# ====================================================================================================
# 3 6
# {}
# ====================================================================================================
# 3 7
# {}
# ====================================================================================================
# 3 8
# {}
# ====================================================================================================
# 3 9
# {462: [193], 464: [194]}
# ====================================================================================================
# 3 10
# {199: [0], 200: [1]}
# ====================================================================================================
# 3 11
# {}
# ====================================================================================================
# 3 12
# {470: [198]}
# ====================================================================================================
# 3 13
# {}
# ====================================================================================================
# 3 14
# {470: [203], 471: [203], 472: [204], 474: [206]}
# ====================================================================================================
# 3 15
# {}
# ====================================================================================================
# 3 16
# {}
# ====================================================================================================
# 3 17
# {}
# ====================================================================================================
# 3 18
# {}
# ====================================================================================================
# 3 19
# {}
# ====================================================================================================
# 3 20
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/w9/673mfrb56v7dvx7hhvw7s6240000gn/T/ipykernel_20338/1477635926.py in <module>
#      15     head_tail_sub2epi = {}
#      16
# ---> 17     gap_pairs = fetch_before_after(en_subset, zh_subset, tbbt_episode, epi2sub)
#      18     for item in gap_pairs:
#      19         temp = before_after_wer_match(en_subset, tbbt_episode, item[0], item[1])
#
# /var/folders/w9/673mfrb56v7dvx7hhvw7s6240000gn/T/ipykernel_20338/2849570325.py in fetch_before_after(en_subset, zh_subset, tbbt_episode, epi2sub)
#      11     while num_sub_token <= num_epi_token*3:
#      12         sub_ids.append(sub_ids[-1]-1)
# ---> 13         num_sub_token += len(en_subset[sub_ids[-1]].strip().split(" "))
#      14     gap_pairs.append([epi_ids, sorted(sub_ids)])
#      15
#
# IndexError: list index out of range
