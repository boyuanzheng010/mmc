# %%
import csv
import json
from copy import deepcopy
import pickle as pkl
csv.field_size_limit(1131072)
# Out:
# 131072

# %%
from annotation.analysis.utils.data_util import generate_all_clusters_combine_speakers
from annotation.analysis.utils.data_util import generate_clusters_no_plural_combine_speakers
from annotation.analysis.utils.data_util import collect_mentions


def read_turkle_annotation_multiple_scene(path):
    """
    Load the annotation_result along with the document
    Output: sentence along with all annotations

    In this version, the input contains annotations from multiple scenes
    Different scenes could be split with sentence_offsets and query_offsets
    """
    output = []
    with open(path, 'r') as f:
        annotation_reader = csv.DictReader(f)
        for instance in annotation_reader:
            inputs = json.loads(instance["Input.json_data"])
            all_sentences = inputs['sentences']
            all_query_spans = inputs['querySpans']
            sentence_offsets = inputs['sentence_offsets']
            query_spans_offsets = inputs['querySpans_offsets']
            all_scene_ids = inputs['scene_ids']
            all_answer_spans = json.loads(instance["Answer.answer_spans"])

            for i in range(len(sentence_offsets) - 1):
                sent_start, sent_end = sentence_offsets[i], sentence_offsets[i + 1]
                query_start, query_end = query_spans_offsets[i], query_spans_offsets[i + 1]
                original_sentences = all_sentences[sent_start: sent_end]
                sentences = []
                for item in original_sentences:
                    temp_sent = []
                    if isinstance(item[0], list):
                        temp_sent.extend(item[0])
                        temp_sent.extend(item[1:])
                        sentences.append(temp_sent)
                    else:
                        sentences.append(item)
                query_spans = all_query_spans[query_start: query_end]
                for item in query_spans:
                    item['sentenceIndex'] -= sentence_offsets[i]

                answer_spans = all_answer_spans[query_start: query_end]
                for item in answer_spans:
                    item['querySpan']['sentenceIndex'] -= sentence_offsets[i]
                    for x in item['span_list']:
                        if x['startToken'] == -1 and x['endToken'] == -1:
                            continue
                        x['sentenceIndex'] -= sentence_offsets[i]

                temp = {
                    "sentences": sentences,
                    "query_spans": query_spans,
                    "answer_spans": answer_spans,
                    "WorkerId": instance['WorkerId'],
                    "scene_id": all_scene_ids[i],
                }
                # Collect mentions into clusters
                temp['clusters_all'] = generate_all_clusters_combine_speakers(temp)
                temp['clusters_no_plural'] = generate_clusters_no_plural_combine_speakers(temp)

                # Collect mentions (For Kappa Cohen)
                answers = collect_mentions(temp)
                temp["answers"] = answers

                # Add to output
                output.append(temp)

    return output

def gather_by_scene(annotations):
    """
    annotations: [sentence along with all annotation_result]
    return {scene_key: [annotations]}
    """
    output = {}
    for instance in annotations:
        key_id = instance['scene_id']
        if key_id not in output:
            output[key_id] = [instance]
        else:
            output[key_id].append(instance)
    return output

# %%
# Load Data and relabel the speaker token
data = read_turkle_annotation_multiple_scene('data/coe_bulk.csv')

# Transform speaker token to string
for item in data:
    temp = []
    for i, (query, answers) in enumerate(item['answers']):
        if isinstance(answers, list):
            for j, answer in enumerate(answers):
                if answer[1]==0 and answer[2]==1 and answer[0]<=(len(item['sentences'])-1):
                    item['answers'][i][1][j] = item['sentences'][answer[0]][0]
                else:
                    item['answers'][i][1][j] = "_".join([str(token) for token in answer])
        else:
            item['answers'][i][1] = [item['answers'][i][1]]
        item['answers'][i][1] = sorted(item['answers'][i][1])
        # print(item['answers'][i])

results = []
results.extend(data)
scenes = gather_by_scene(results)

# %%
one_way = {}
two_way = {}
for item in scenes:
    if len(scenes[item])==1:
        one_way[item] = scenes[item]
    else:
        two_way[item] = scenes[item]

# %%
print(len(two_way))
print(len(one_way))
# Out:
# 23
# 107

# %%
disagreed_num = 0
all_num = 0
union_num = 0
for item in two_way:
    print(item)
    temp = two_way[item]
    for a, b in zip(temp[0]['answers'], temp[1]['answers']):
        all_num += 1
        if a!=b:
            disagreed_num += 1
            print(a)
            print(b)
            print()
            temp = deepcopy(a[1])
            temp.extend(b[1])
            union_answers = [token for token in temp if token!="notMention"]
            if len(union_answers)!=0:
                union_num += 1
            else:
                print(a)
                print(b)
                print(union_answers)
                print()
    print("=="*50)
# Out:
# s07e17c11t
# [(0, 14, 15), ['notPresent']]
# [(0, 14, 15), ['notMention']]
#
# [(1, 20, 21), ['notPresent']]
# [(1, 20, 21), ['notMention']]
#
# [(1, 23, 24), ['1_20_21']]
# [(1, 23, 24), ['notMention']]
#
# [(1, 40, 42), ['notPresent']]
# [(1, 40, 42), ['1_37_38']]
#
# [(4, 2, 3), ['notPresent']]
# [(4, 2, 3), ['1_40_42']]
#
# [(4, 4, 5), ['notPresent']]
# [(4, 4, 5), ['notMention']]
#
# [(4, 4, 6), ['4_2_3']]
# [(4, 4, 6), ['1_40_42']]
#
# [(4, 8, 9), ['4_2_3']]
# [(4, 8, 9), ['1_40_42']]
#
# [(4, 29, 30), ['notPresent']]
# [(4, 29, 30), ['notMention']]
#
# [(5, 6, 7), ['notPresent']]
# [(5, 6, 7), ['notMention']]
#
# [(6, 5, 6), ['notPresent']]
# [(6, 5, 6), ['notMention']]
#
# [(8, 11, 12), ['notPresent']]
# [(8, 11, 12), ['Leonard']]
#
# [(8, 19, 21), ['notPresent']]
# [(8, 19, 21), ['4_2_3']]
#
# ====================================================================================================
# s07e17c12t
# [(0, 16, 17), ['Emily']]
# [(0, 16, 17), ['notPresent']]
#
# [(0, 17, 18), ['0_11_12']]
# [(0, 17, 18), ['Raj']]
#
# [(0, 21, 22), ['Emily']]
# [(0, 21, 22), ['notPresent']]
#
# [(0, 25, 26), ['0_11_12']]
# [(0, 25, 26), ['Raj']]
#
# [(0, 27, 28), ['0_21_22']]
# [(0, 27, 28), ['notPresent']]
#
# [(0, 30, 31), ['0_11_12']]
# [(0, 30, 31), ['Raj']]
#
# [(0, 32, 38), ['0_11_12']]
# [(0, 32, 38), ['Raj']]
#
# [(0, 40, 42), ['notPresent']]
# [(0, 40, 42), ['notMention']]
#
# [(0, 44, 45), ['0_11_12']]
# [(0, 44, 45), ['Raj']]
#
# [(1, 4, 5), ['Emily']]
# [(1, 4, 5), ['0_16_17']]
#
# [(3, 2, 3), ['Amy']]
# [(3, 2, 3), ['notPresent']]
#
# [(3, 21, 22), ['notPresent']]
# [(3, 21, 22), ['notMention']]
#
# [(3, 24, 27), ['notPresent']]
# [(3, 24, 27), ['Raj']]
#
# [(3, 42, 46), ['1_4_5']]
# [(3, 42, 46), ['Emily']]
#
# [(3, 47, 48), ['notPresent']]
# [(3, 47, 48), ['notMention']]
#
# [(4, 5, 11), ['notPresent']]
# [(4, 5, 11), ['3_25_27']]
#
# [(4, 9, 11), ['notPresent']]
# [(4, 9, 11), ['notMention']]
#
# [(5, 6, 7), ['notPresent']]
# [(5, 6, 7), ['notMention']]
#
# [(5, 8, 11), ['notPresent']]
# [(5, 8, 11), ['notMention']]
#
# [(5, 13, 14), ['notMention']]
# [(5, 13, 14), ['Emily', 'Raj']]
#
# [(5, 18, 19), ['notPresent']]
# [(5, 18, 19), ['notMention']]
#
# [(5, 23, 26), ['notPresent']]
# [(5, 23, 26), ['notMention']]
#
# [(7, 9, 12), ['notPresent']]
# [(7, 9, 12), ['notMention']]
#
# [(7, 9, 10), ['notPresent']]
# [(7, 9, 10), ['notMention']]
#
# [(9, 2, 7), ['notPresent']]
# [(9, 2, 7), ['notMention']]
#
# [(9, 3, 7), ['notPresent']]
# [(9, 3, 7), ['notMention']]
#
# [(9, 12, 14), ['notPresent']]
# [(9, 12, 14), ['9_5_7']]
#
# ====================================================================================================
# s07e18c00t
# [(2, 9, 10), ['notPresent']]
# [(2, 9, 10), ['notMention']]
#
# [(5, 2, 6), ['notPresent']]
# [(5, 2, 6), ['notMention']]
#
# [(6, 2, 3), ['0_8_9']]
# [(6, 2, 3), ['1_7_8']]
#
# [(7, 5, 6), ['notPresent']]
# [(7, 5, 6), ['notMention']]
#
# [(7, 7, 8), ['0_8_9']]
# [(7, 7, 8), ['6_2_3']]
#
# [(7, 14, 15), ['4_6_7']]
# [(7, 14, 15), ['5_2_3']]
#
# [(7, 16, 17), ['7_7_8']]
# [(7, 16, 17), ['6_2_3']]
#
# [(7, 17, 26), ['notPresent']]
# [(7, 17, 26), ['notMention']]
#
# [(8, 4, 5), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
# [(8, 4, 5), ['Amy', 'Bernadette', 'Leonard', 'Raj']]
#
# [(10, 4, 5), ['Stuart']]
# [(10, 4, 5), ['notPresent']]
#
# [(11, 4, 5), ['Stuart']]
# [(11, 4, 5), ['notMention']]
#
# [(12, 4, 5), ['notPresent']]
# [(12, 4, 5), ['notMention']]
#
# [(13, 4, 5), ['0_8_9']]
# [(13, 4, 5), ['7_7_8']]
#
# [(13, 11, 12), ['8_4_5']]
# [(13, 11, 12), ['Leonard', 'Raj']]
#
# [(13, 14, 15), ['notPresent']]
# [(13, 14, 15), ['notMention']]
#
# [(13, 15, 16), ['13_11_12']]
# [(13, 15, 16), ['Amy', 'Leonard', 'Raj']]
#
# [(13, 18, 19), ['13_15_16']]
# [(13, 18, 19), ['Bernadette', 'Leonard', 'Raj']]
#
# [(13, 22, 29), ['notPresent']]
# [(13, 22, 29), ['notMention']]
#
# [(13, 25, 26), ['13_4_5']]
# [(13, 25, 26), ['6_2_3']]
#
# [(14, 6, 7), ['13_22_29']]
# [(14, 6, 7), ['notMention']]
#
# [(16, 2, 3), ['notPresent']]
# [(16, 2, 3), ['notMention']]
#
# [(16, 4, 5), ['8_4_5']]
# [(16, 4, 5), ['Amy', 'Bernadette', 'Raj']]
#
# [(16, 4, 6), ['8_4_5']]
# [(16, 4, 6), ['notPresent']]
#
# [(16, 9, 10), ['notPresent']]
# [(16, 9, 10), ['notMention']]
#
# [(18, 6, 7), ['4_6_7']]
# [(18, 6, 7), ['6_6_7']]
#
# [(18, 31, 32), ['notPresent']]
# [(18, 31, 32), ['notMention']]
#
# [(21, 4, 5), ['Stuart']]
# [(21, 4, 5), ['20_4_5']]
#
# [(22, 7, 8), ['Amy', 'Bernadette', 'Leonard', 'Raj']]
# [(22, 7, 8), ['Leonard', 'Raj']]
#
# [(22, 7, 9), ['Amy', 'Bernadette', 'Leonard', 'Raj']]
# [(22, 7, 9), ['notPresent']]
#
# [(23, 2, 3), ['Stuart']]
# [(23, 2, 3), ['20_4_5']]
#
# [(24, 3, 4), ['notPresent']]
# [(24, 3, 4), ['notMention']]
#
# [(25, 4, 5), ['notPresent']]
# [(25, 4, 5), ['notMention']]
#
# [(26, 2, 3), ['notPresent']]
# [(26, 2, 3), ['notMention']]
#
# [(26, 6, 7), ['25_4_5']]
# [(26, 6, 7), ['notMention']]
#
# [(27, 7, 11), ['notPresent']]
# [(27, 7, 11), ['notMention']]
#
# [(27, 7, 8), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
# [(27, 7, 8), ['Amy', 'Leonard', 'Penny', 'Raj']]
#
# [(30, 4, 10), ['notPresent']]
# [(30, 4, 10), ['notMention']]
#
# [(32, 12, 18), ['notPresent']]
# [(32, 12, 18), ['notMention']]
#
# [(32, 16, 18), ['Stuart']]
# [(32, 16, 18), ['23_2_3']]
#
# [(33, 6, 7), ['Stuart']]
# [(33, 6, 7), ['32_16_17']]
#
# [(33, 10, 11), ['33_6_9']]
# [(33, 10, 11), ['32_16_17']]
#
# [(34, 6, 7), ['34_4_5']]
# [(34, 6, 7), ['32_16_17']]
#
# [(35, 3, 4), ['Stuart']]
# [(35, 3, 4), ['32_16_17']]
#
# [(35, 16, 18), ['notPresent']]
# [(35, 16, 18), ['notMention']]
#
# [(36, 2, 3), ['notPresent']]
# [(36, 2, 3), ['notMention']]
#
# ====================================================================================================
# s07e18c01t
# [(0, 11, 19), ['0_7_8']]
# [(0, 11, 19), ['notPresent']]
#
# [(0, 14, 19), ['0_7_8']]
# [(0, 14, 19), ['notMention']]
#
# [(0, 17, 19), ['notPresent']]
# [(0, 17, 19), ['notMention']]
#
# [(1, 2, 8), ['notMention']]
# [(1, 2, 8), ['0_15_16']]
#
# [(1, 3, 8), ['0_14_19']]
# [(1, 3, 8), ['notMention']]
#
# [(1, 6, 8), ['0_17_19']]
# [(1, 6, 8), ['notMention']]
#
# [(1, 10, 11), ['notPresent']]
# [(1, 10, 11), ['notMention']]
#
# [(1, 13, 14), ['notPresent']]
# [(1, 13, 14), ['Penny']]
#
# [(2, 10, 11), ['notPresent']]
# [(2, 10, 11), ['notMention']]
#
# [(2, 14, 15), ['2_10_11']]
# [(2, 14, 15), ['notMention']]
#
# [(4, 2, 6), ['1_13_14']]
# [(4, 2, 6), ['notMention']]
#
# [(4, 5, 6), ['1_13_14']]
# [(4, 5, 6), ['notMention']]
#
# [(4, 7, 8), ['2_10_11']]
# [(4, 7, 8), ['notMention']]
#
# [(5, 5, 6), ['Amy', 'Bernadette', 'Penny']]
# [(5, 5, 6), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
#
# [(5, 7, 8), ['Raj']]
# [(5, 7, 8), ['2_2_3']]
#
# [(5, 9, 13), ['notPresent']]
# [(5, 9, 13), ['notMention']]
#
# [(5, 12, 13), ['notPresent']]
# [(5, 12, 13), ['notMention']]
#
# [(5, 14, 15), ['2_10_11']]
# [(5, 14, 15), ['notMention']]
#
# [(5, 17, 18), ['notPresent']]
# [(5, 17, 18), ['notMention']]
#
# [(5, 21, 22), ['2_10_11']]
# [(5, 21, 22), ['notMention']]
#
# [(5, 26, 27), ['5_21_22']]
# [(5, 26, 27), ['notMention']]
#
# [(6, 4, 5), ['notPresent']]
# [(6, 4, 5), ['notMention']]
#
# [(6, 7, 8), ['6_4_5']]
# [(6, 7, 8), ['notMention']]
#
# [(6, 10, 12), ['notPresent']]
# [(6, 10, 12), ['notMention']]
#
# [(6, 12, 13), ['notPresent']]
# [(6, 12, 13), ['notMention']]
#
# [(7, 4, 5), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
# [(7, 4, 5), ['Amy']]
#
# [(7, 6, 7), ['7_4_5']]
# [(7, 6, 7), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
#
# [(7, 11, 12), ['7_4_5']]
# [(7, 11, 12), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
#
# [(9, 9, 10), ['2_10_11']]
# [(9, 9, 10), ['notMention']]
#
# [(9, 26, 27), ['9_24_25']]
# [(9, 26, 27), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
#
# [(9, 28, 29), ['notPresent']]
# [(9, 28, 29), ['notMention']]
#
# [(9, 30, 33), ['notPresent']]
# [(9, 30, 33), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
#
# [(9, 32, 33), ['9_24_25']]
# [(9, 32, 33), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
#
# [(9, 34, 35), ['Stuart']]
# [(9, 34, 35), ['notPresent']]
#
# [(10, 5, 6), ['Bernadette']]
# [(10, 5, 6), ['9_6_7']]
#
# [(10, 9, 13), ['10_7_8']]
# [(10, 9, 13), ['notPresent']]
#
# [(11, 4, 5), ['10_9_13']]
# [(11, 4, 5), ['10_11_13']]
#
# [(11, 8, 12), ['notPresent']]
# [(11, 8, 12), ['10_11_13']]
#
# [(12, 6, 10), ['12_4_6']]
# [(12, 6, 10), ['notPresent']]
#
# [(13, 6, 8), ['12_4_6']]
# [(13, 6, 8), ['notMention']]
#
# [(14, 4, 5), ['9_24_25']]
# [(14, 4, 5), ['Amy', 'Bernadette']]
#
# [(14, 6, 9), ['14_4_5']]
# [(14, 6, 9), ['11_8_12']]
#
# [(14, 18, 19), ['notPresent']]
# [(14, 18, 19), ['notMention']]
#
# [(14, 18, 21), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
# [(14, 18, 21), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
#
# [(14, 20, 21), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
# [(14, 20, 21), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
#
# [(14, 24, 25), ['14_20_21']]
# [(14, 24, 25), ['Amy', 'Bernadette', 'Leonard', 'Penny']]
#
# [(14, 26, 28), ['14_20_21']]
# [(14, 26, 28), ['notPresent']]
#
# [(15, 3, 4), ['notPresent']]
# [(15, 3, 4), ['notMention']]
#
# [(15, 9, 11), ['14_26_28']]
# [(15, 9, 11), ['notMention']]
#
# [(16, 2, 6), ['notPresent']]
# [(16, 2, 6), ['notMention']]
#
# [(16, 5, 6), ['15_7_12']]
# [(16, 5, 6), ['notMention']]
#
# [(17, 4, 5), ['15_7_8']]
# [(17, 4, 5), ['notMention']]
#
# [(17, 7, 9), ['notPresent']]
# [(17, 7, 9), ['notMention']]
#
# [(18, 2, 3), ['Bernadette']]
# [(18, 2, 3), ['9_6_7']]
#
# [(18, 5, 6), ['Bernadette']]
# [(18, 5, 6), ['18_2_3']]
#
# [(19, 2, 3), ['notPresent']]
# [(19, 2, 3), ['notMention']]
#
# ====================================================================================================
# s07e18c08t
# [(0, 3, 4), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(0, 3, 4), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
#
# [(2, 10, 11), ['notPresent']]
# [(2, 10, 11), ['1_33_34']]
#
# [(4, 3, 6), ['Amy']]
# [(4, 3, 6), ['notPresent']]
#
# [(5, 25, 26), ['notPresent']]
# [(5, 25, 26), ['notMention']]
#
# [(6, 12, 15), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(6, 12, 15), ['notPresent']]
#
# [(6, 14, 15), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(6, 14, 15), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
#
# [(7, 4, 5), ['Penny']]
# [(7, 4, 5), ['Stuart']]
#
# [(9, 4, 5), ['Leonard', 'Penny']]
# [(9, 4, 5), ['Penny']]
#
# [(9, 6, 11), ['9_4_5']]
# [(9, 6, 11), ['7_4_7']]
#
# [(12, 3, 4), ['notPresent']]
# [(12, 3, 4), ['notMention']]
#
# [(14, 25, 26), ['notPresent']]
# [(14, 25, 26), ['11_4_5']]
#
# [(15, 12, 14), ['Leonard', 'Penny']]
# [(15, 12, 14), ['15_9_11']]
#
# [(15, 21, 22), ['15_18_19']]
# [(15, 21, 22), ['Leonard']]
#
# [(15, 28, 29), ['15_18_19']]
# [(15, 28, 29), ['Leonard']]
#
# [(15, 30, 31), ['15_16_17']]
# [(15, 30, 31), ['Penny']]
#
# [(15, 50, 53), ['notPresent']]
# [(15, 50, 53), ['15_45_47']]
#
# [(18, 12, 13), ['Amy', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(18, 12, 13), ['Amy', 'Leonard', 'Penny', 'Raj']]
#
# ====================================================================================================
# s07e18c09t
# [(2, 25, 26), ['notPresent']]
# [(2, 25, 26), ['notMention']]
#
# [(4, 12, 15), ['notPresent']]
# [(4, 12, 15), ['3_13_14']]
#
# [(4, 14, 15), ['notPresent']]
# [(4, 14, 15), ['3_13_14']]
#
# [(5, 6, 7), ['Sheldon']]
# [(5, 6, 7), ['notPresent']]
#
# [(8, 4, 5), ['7_6_7']]
# [(8, 4, 5), ['6_7_9']]
#
# [(8, 7, 9), ['notPresent']]
# [(8, 7, 9), ['6_11_12']]
#
# [(8, 18, 19), ['8_4_5']]
# [(8, 18, 19), ['6_7_9']]
#
# [(10, 5, 6), ['Howard', 'Sheldon']]
# [(10, 5, 6), ['notMention']]
#
# [(10, 8, 9), ['notPresent']]
# [(10, 8, 9), ['9_2_3']]
#
# [(10, 10, 23), ['10_8_9']]
# [(10, 10, 23), ['notPresent']]
#
# [(10, 26, 27), ['7_6_7']]
# [(10, 26, 27), ['8_4_5']]
#
# [(10, 33, 34), ['10_26_27']]
# [(10, 33, 34), ['8_4_5']]
#
# [(10, 41, 42), ['10_26_27']]
# [(10, 41, 42), ['10_33_34']]
#
# [(11, 12, 15), ['11_9_10']]
# [(11, 12, 15), ['10_52_55']]
#
# [(12, 2, 6), ['notPresent']]
# [(12, 2, 6), ['notMention']]
#
# [(13, 10, 12), ['2_42_44']]
# [(13, 10, 12), ['12_17_19']]
#
# ====================================================================================================
# s07e18c10t
# [(3, 10, 11), ['notPresent']]
# [(3, 10, 11), ['1_7_8']]
#
# [(3, 17, 18), ['notPresent']]
# [(3, 17, 18), ['1_7_8']]
#
# [(4, 9, 10), ['3_10_13']]
# [(4, 9, 10), ['3_17_18']]
#
# [(4, 14, 16), ['4_4_5']]
# [(4, 14, 16), ['notPresent']]
#
# [(4, 19, 20), ['notPresent']]
# [(4, 19, 20), ['4_9_10']]
#
# [(5, 6, 7), ['4_19_20']]
# [(5, 6, 7), ['4_9_10']]
#
# [(6, 7, 8), ['notPresent']]
# [(6, 7, 8), ['4_9_10']]
#
# [(8, 18, 23), ['notPresent']]
# [(8, 18, 23), ['notMention']]
#
# [(10, 30, 33), ['10_28_29']]
# [(10, 30, 33), ['Mrs Cooper']]
#
# [(10, 37, 38), ['notPresent']]
# [(10, 37, 38), ['10_23_25']]
#
# ====================================================================================================
# s01e01c00f
# [(0, 4, 7), ['0_2_3']]
# [(0, 4, 7), ['notPresent']]
#
# [(0, 4, 5), ['0_2_3']]
# [(0, 4, 5), ['notPresent']]
#
# [(0, 10, 16), ['0_8_9']]
# [(0, 10, 16), ['notPresent']]
#
# [(1, 7, 9), ['0_11_13']]
# [(1, 7, 9), ['0_10_16']]
#
# [(1, 18, 19), ['1_7_9']]
# [(1, 18, 19), ['0_10_16']]
#
# [(2, 12, 13), ['1_18_19']]
# [(2, 12, 13), ['1_7_9']]
#
# [(3, 5, 6), ['2_12_13']]
# [(3, 5, 6), ['1_7_9']]
#
# [(5, 14, 15), ['notPresent']]
# [(5, 14, 15), ['5_7_8']]
#
# [(5, 16, 27), ['5_14_15']]
# [(5, 16, 27), ['notPresent']]
#
# [(6, 4, 6), ['5_14_15']]
# [(6, 4, 6), ['5_11_13']]
#
# [(12, 4, 6), ['notPresent']]
# [(12, 4, 6), ['8_5_7']]
#
# [(14, 2, 3), ['notPresent']]
# [(14, 2, 3), ['notMention']]
#
# [(14, 7, 9), ['notPresent']]
# [(14, 7, 9), ['9_11_13']]
#
# [(16, 18, 20), ['16_16_17']]
# [(16, 18, 20), ['notPresent']]
#
# [(18, 2, 4), ['notPresent']]
# [(18, 2, 4), ['Ross Geller']]
#
# [(19, 2, 3), ['Joey Tribbiani']]
# [(19, 2, 3), ['Ross Geller']]
#
# [(19, 5, 6), ['Joey Tribbiani']]
# [(19, 5, 6), ['Ross Geller']]
#
# [(27, 14, 16), ['notPresent']]
# [(27, 14, 16), ['27_9_11']]
#
# [(31, 9, 12), ['notPresent']]
# [(31, 9, 12), ['notMention']]
#
# [(31, 11, 12), ['29_9_10']]
# [(31, 11, 12), ['22_2_3']]
#
# [(32, 6, 7), ['31_13_14']]
# [(32, 6, 7), ['31_11_12']]
#
# [(33, 12, 13), ['notPresent']]
# [(33, 12, 13), ['32_6_10']]
#
# [(34, 7, 9), ['34_5_6']]
# [(34, 7, 9), ['notPresent']]
#
# [(35, 14, 15), ['notPresent']]
# [(35, 14, 15), ['33_12_13']]
#
# [(38, 27, 29), ['38_26_27']]
# [(38, 27, 29), ['notPresent']]
#
# [(39, 2, 4), ['notPresent']]
# [(39, 2, 4), ['38_27_29']]
#
# [(39, 13, 15), ['notPresent']]
# [(39, 13, 15), ['39_2_4']]
#
# [(43, 4, 5), ['notPresent']]
# [(43, 4, 5), ['notMention']]
#
# [(43, 11, 12), ['notPresent']]
# [(43, 11, 12), ['notMention']]
#
# [(45, 8, 14), ['45_6_7']]
# [(45, 8, 14), ['Rachel Green']]
#
# [(45, 10, 14), ['notPresent']]
# [(45, 10, 14), ['45_8_9']]
#
# [(45, 15, 16), ['Chandler Bing', 'Joey Tribbiani', 'Phoebe Buffay', 'Ross Geller']]
# [(45, 15, 16), ['45_4_5']]
#
# [(48, 6, 7), ['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']]
# [(48, 6, 7), ['45_4_5', 'Monica Geller']]
#
# [(48, 11, 12), ['Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']]
# [(48, 11, 12), ['48_6_7']]
#
# [(49, 4, 5), ['notPresent']]
# [(49, 4, 5), ['notMention']]
#
# [(49, 37, 43), ['notPresent']]
# [(49, 37, 43), ['49_33_36']]
#
# [(49, 45, 46), ['notPresent']]
# [(49, 45, 46), ['notMention']]
#
# [(49, 45, 49), ['notPresent']]
# [(49, 45, 49), ['notMention']]
#
# [(49, 47, 49), ['notPresent']]
# [(49, 47, 49), ['notMention']]
#
# [(49, 60, 63), ['notPresent']]
# [(49, 60, 63), ['49_33_36']]
#
# [(49, 91, 92), ['49_81_82']]
# [(49, 91, 92), ['49_65_66']]
#
# [(49, 123, 124), ['notPresent']]
# [(49, 123, 124), ['49_114_115']]
#
# [(50, 2, 3), ['notPresent']]
# [(50, 2, 3), ['49_147_155']]
#
# [(50, 7, 9), ['notPresent']]
# [(50, 7, 9), ['49_16_18']]
#
# [(51, 11, 13), ['notPresent']]
# [(51, 11, 13), ['51_7_8']]
#
# ====================================================================================================
# s01e01c01f
# [(0, 18, 19), ['notPresent']]
# [(0, 18, 19), ['0_7_10']]
#
# [(5, 2, 3), ['0_12_13']]
# [(5, 2, 3), ['notPresent']]
#
# [(6, 11, 12), ['5_2_3']]
# [(6, 11, 12), ['6_5_6']]
#
# [(6, 13, 15), ['notPresent']]
# [(6, 13, 15), ['6_7_9']]
#
# [(6, 17, 18), ['5_2_3']]
# [(6, 17, 18), ['6_5_6']]
#
# [(6, 19, 21), ['notPresent']]
# [(6, 19, 21), ['6_13_15']]
#
# [(7, 3, 4), ['6_5_6']]
# [(7, 3, 4), ['6_17_18']]
#
# [(7, 5, 7), ['notPresent']]
# [(7, 5, 7), ['6_19_21']]
#
# [(7, 12, 13), ['7_3_4']]
# [(7, 12, 13), ['7_9_10']]
#
# [(7, 14, 16), ['notPresent']]
# [(7, 14, 16), ['7_5_7']]
#
# [(8, 27, 28), ['Rachel Green']]
# [(8, 27, 28), ['8_20_21']]
#
# [(8, 32, 33), ['Rachel Green']]
# [(8, 32, 33), ['8_27_28']]
#
# [(8, 56, 58), ['notPresent']]
# [(8, 56, 58), ['8_39_41']]
#
# [(8, 85, 87), ['notPresent']]
# [(8, 85, 87), ['8_73_75']]
#
# [(8, 88, 89), ['notMention']]
# [(8, 88, 89), ['Rachel Green']]
#
# [(9, 2, 3), ['notPresent']]
# [(9, 2, 3), ['Rachel Green']]
#
# [(9, 6, 7), ['8_95_96']]
# [(9, 6, 7), ['8_5_6']]
#
# [(10, 4, 5), ['9_6_7']]
# [(10, 4, 5), ['8_5_6']]
#
# [(12, 7, 9), ['12_5_6']]
# [(12, 7, 9), ['notPresent']]
#
# [(12, 17, 18), ['10_4_5']]
# [(12, 17, 18), ['8_5_6']]
#
# [(14, 2, 5), ['notPresent']]
# [(14, 2, 5), ['13_16_20']]
#
# [(14, 17, 21), ['notPresent']]
# [(14, 17, 21), ['notMention']]
#
# [(17, 14, 19), ['notPresent']]
# [(17, 14, 19), ['notMention']]
#
# [(17, 20, 26), ['notPresent']]
# [(17, 20, 26), ['8_92_94']]
#
# [(18, 23, 24), ['18_16_17']]
# [(18, 23, 24), ['Chandler Bing']]
#
# [(18, 26, 28), ['notPresent']]
# [(18, 26, 28), ['notMention']]
#
# [(20, 5, 10), ['20_3_4']]
# [(20, 5, 10), ['notPresent']]
#
# [(21, 9, 10), ['notPresent']]
# [(21, 9, 10), ['21_6_7']]
#
# [(23, 4, 5), ['notPresent']]
# [(23, 4, 5), ['notMention']]
#
# [(24, 4, 5), ['24_2_3']]
# [(24, 4, 5), ['22_4_5']]
#
# [(25, 2, 8), ['24_4_5']]
# [(25, 2, 8), ['Paul the Wine Guy']]
#
# [(25, 3, 6), ['25_2_3']]
# [(25, 3, 6), ['Paul the Wine Guy']]
#
# [(25, 7, 8), ['25_2_3']]
# [(25, 7, 8), ['Paul the Wine Guy']]
#
# [(26, 2, 3), ['25_2_3']]
# [(26, 2, 3), ['Paul the Wine Guy']]
#
# [(26, 4, 7), ['26_2_3']]
# [(26, 4, 7), ['Paul the Wine Guy']]
#
# [(26, 10, 11), ['Ross Geller']]
# [(26, 10, 11), ['Monica Geller']]
#
# [(26, 22, 25), ['26_20_21']]
# [(26, 22, 25), ['Paul the Wine Guy']]
#
# [(27, 2, 3), ['Paul the Wine Guy']]
# [(27, 2, 3), ['26_20_21']]
#
# [(29, 2, 3), ['notPresent']]
# [(29, 2, 3), ['26_12_16']]
#
# [(35, 5, 6), ['notPresent']]
# [(35, 5, 6), ['Paul the Wine Guy']]
#
# [(35, 9, 12), ['35_7_8']]
# [(35, 9, 12), ['35_5_6']]
#
# [(36, 3, 4), ['Paul the Wine Guy']]
# [(36, 3, 4), ['35_7_8']]
#
# [(36, 5, 6), ['notPresent']]
# [(36, 5, 6), ['35_10_11']]
#
# [(36, 8, 9), ['notPresent']]
# [(36, 8, 9), ['35_10_11']]
#
# [(36, 11, 12), ['Paul the Wine Guy']]
# [(36, 11, 12), ['35_7_8']]
#
# [(36, 14, 16), ['notPresent']]
# [(36, 14, 16), ['notMention']]
#
# [(37, 7, 8), ['Paul the Wine Guy']]
# [(37, 7, 8), ['35_7_8']]
#
# [(37, 9, 10), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']]
# [(37, 9, 10), ['notPresent']]
#
# [(37, 16, 17), ['Paul the Wine Guy']]
# [(37, 16, 17), ['notPresent']]
#
# [(39, 6, 7), ['Paul the Wine Guy']]
# [(39, 6, 7), ['37_18_19']]
#
# [(39, 9, 10), ['37_18_19']]
# [(39, 9, 10), ['39_6_8']]
#
# [(41, 4, 5), ['notPresent']]
# [(41, 4, 5), ['notMention']]
#
# [(44, 4, 5), ['Paul the Wine Guy']]
# [(44, 4, 5), ['37_18_19']]
#
# [(46, 12, 13), ['notPresent']]
# [(46, 12, 13), ['Paul the Wine Guy']]
#
# [(50, 9, 11), ['notPresent']]
# [(50, 9, 11), ['49_11_13']]
#
# [(50, 14, 15), ['notPresent']]
# [(50, 14, 15), ['49_9_10']]
#
# ====================================================================================================
# s01e01c02f
# [(0, 6, 8), ['notPresent']]
# [(0, 6, 8), ['0_2_3']]
#
# [(0, 8, 9), ['notPresent']]
# [(0, 8, 9), ['0_2_3']]
#
# [(0, 20, 22), ['notPresent']]
# [(0, 20, 22), ['0_16_18']]
#
# [(0, 20, 21), ['notPresent']]
# [(0, 20, 21), ['0_16_17']]
#
# [(0, 23, 24), ['notPresent']]
# [(0, 23, 24), ['0_20_21']]
#
# [(0, 23, 25), ['notPresent']]
# [(0, 23, 25), ['0_20_22']]
#
# [(0, 35, 36), ['notPresent']]
# [(0, 35, 36), ['0_16_17']]
#
# ====================================================================================================
# s01e01c03f
# [(0, 28, 33), ['notPresent']]
# [(0, 28, 33), ['0_7_12']]
#
# [(0, 36, 40), ['notPresent']]
# [(0, 36, 40), ['0_21_25']]
#
# [(2, 2, 3), ['notPresent']]
# [(2, 2, 3), ['1_4_6']]
#
# [(4, 7, 8), ['notPresent']]
# [(4, 7, 8), ['3_4_5']]
#
# [(5, 2, 3), ['notPresent']]
# [(5, 2, 3), ['4_9_14']]
#
# [(7, 4, 6), ['notPresent']]
# [(7, 4, 6), ['1_4_6']]
#
# [(8, 2, 3), ['notPresent']]
# [(8, 2, 3), ['notMention']]
#
# [(12, 5, 6), ['Ross Geller']]
# [(12, 5, 6), ['Chandler Bing']]
#
# [(14, 4, 5), ['notPresent']]
# [(14, 4, 5), ['notMention']]
#
# [(16, 4, 6), ['notPresent']]
# [(16, 4, 6), ['notMention']]
#
# ====================================================================================================
# s01e01c04f
# [(0, 4, 6), ['notPresent']]
# [(0, 4, 6), ['notMention']]
#
# [(1, 7, 10), ['1_5_6']]
# [(1, 7, 10), ['Paul the Wine Guy']]
#
# [(1, 17, 18), ['notPresent']]
# [(1, 17, 18), ['Monica Geller']]
#
# [(2, 19, 20), ['notPresent']]
# [(2, 19, 20), ['2_7_8']]
#
# [(3, 2, 3), ['2_9_10']]
# [(3, 2, 3), ['2_2_4']]
#
# [(6, 5, 7), ['notPresent']]
# [(6, 5, 7), ['5_13_15']]
#
# ====================================================================================================
# s01e01c05f
# [(0, 4, 5), ['1_0_1']]
# [(0, 4, 5), ['Rachel Green']]
#
# [(0, 8, 9), ['1_0_1']]
# [(0, 8, 9), ['Rachel Green']]
#
# [(0, 27, 28), ['notPresent']]
# [(0, 27, 28), ['0_16_17']]
#
# [(0, 31, 32), ['notPresent']]
# [(0, 31, 32), ['0_16_17']]
#
# [(0, 60, 63), ['notPresent']]
# [(0, 60, 63), ['0_51_53']]
#
# [(0, 70, 71), ['notPresent']]
# [(0, 70, 71), ['0_65_66']]
#
# [(0, 79, 86), ['notPresent']]
# [(0, 79, 86), ['notMention']]
#
# [(0, 83, 84), ['0_81_82']]
# [(0, 83, 84), ['Rachel Green']]
#
# [(0, 92, 95), ['notPresent']]
# [(0, 92, 95), ['notMention']]
#
# ====================================================================================================
# s01e01c06f
# [(4, 5, 6), ['Chandler Bing', 'Joey Tribbiani']]
# [(4, 5, 6), ['4_3_4']]
#
# [(4, 40, 41), ['notPresent']]
# [(4, 40, 41), ['4_32_38']]
#
# [(4, 51, 52), ['Chandler Bing', 'Joey Tribbiani']]
# [(4, 51, 52), ['4_3_4']]
#
# [(4, 55, 56), ['notPresent']]
# [(4, 55, 56), ['4_9_11']]
#
# [(5, 12, 17), ['5_10_11']]
# [(5, 12, 17), ['notPresent']]
#
# [(5, 25, 27), ['notPresent']]
# [(5, 25, 27), ['5_12_15']]
#
# [(5, 29, 30), ['notPresent']]
# [(5, 29, 30), ['5_25_27']]
#
# [(5, 41, 46), ['5_39_40']]
# [(5, 41, 46), ['notPresent']]
#
# [(5, 47, 49), ['notPresent']]
# [(5, 47, 49), ['5_41_44']]
#
# [(6, 2, 4), ['notPresent']]
# [(6, 2, 4), ['5_25_27']]
#
# [(6, 28, 31), ['6_26_27']]
# [(6, 28, 31), ['6_15_17']]
#
# [(6, 34, 45), ['6_30_31']]
# [(6, 34, 45), ['6_28_31']]
#
# [(6, 38, 40), ['6_30_31']]
# [(6, 38, 40), ['notPresent']]
#
# [(6, 42, 45), ['6_30_31']]
# [(6, 42, 45), ['notPresent']]
#
# [(6, 46, 47), ['notPresent']]
# [(6, 46, 47), ['Ross Geller']]
#
# [(6, 49, 50), ['notPresent']]
# [(6, 49, 50), ['6_28_31']]
#
# [(6, 65, 66), ['6_64_65']]
# [(6, 65, 66), ['6_62_65']]
#
# ====================================================================================================
# s01e01c07f
# [(2, 2, 3), ['notPresent']]
# [(2, 2, 3), ['1_5_6']]
#
# [(2, 4, 12), ['2_2_3']]
# [(2, 4, 12), ['notPresent']]
#
# [(3, 8, 11), ['notPresent']]
# [(3, 8, 11), ['2_6_9']]
#
# [(7, 4, 5), ['notPresent']]
# [(7, 4, 5), ['notMention']]
#
# [(7, 8, 9), ['notPresent']]
# [(7, 8, 9), ['notMention']]
#
# [(11, 9, 10), ['6_4_5']]
# [(11, 9, 10), ['0_4_5']]
#
# [(12, 9, 12), ['notPresent']]
# [(12, 9, 12), ['2_6_9']]
#
# ====================================================================================================
# s01e01c08f
# [(0, 2, 3), ['Priest On Tv']]
# [(0, 2, 3), ['notPresent']]
#
# [(1, 5, 6), ['notPresent']]
# [(1, 5, 6), ['0_8_11']]
#
# [(1, 7, 8), ['notPresent']]
# [(1, 7, 8), ['0_13_14']]
#
# ====================================================================================================
# s01e01c09f
# [(0, 9, 10), ['Chandler Bing', 'Joey Tribbiani']]
# [(0, 9, 10), ['notPresent']]
#
# [(0, 19, 21), ['notPresent']]
# [(0, 19, 21), ['0_4_6']]
#
# [(0, 39, 40), ['Chandler Bing', 'Joey Tribbiani']]
# [(0, 39, 40), ['0_9_10']]
#
# [(1, 18, 19), ['notPresent']]
# [(1, 18, 19), ['1_16_17']]
#
# [(1, 22, 23), ['1_16_17']]
# [(1, 22, 23), ['1_18_19']]
#
# [(2, 2, 3), ['1_16_17']]
# [(2, 2, 3), ['1_22_23']]
#
# [(3, 4, 5), ['notPresent']]
# [(3, 4, 5), ['notMention']]
#
# ====================================================================================================
# s01e01c10f
# [(1, 2, 3), ['notPresent']]
# [(1, 2, 3), ['0_4_5']]
#
# [(3, 8, 9), ['notPresent']]
# [(3, 8, 9), ['0_11_12']]
#
# [(5, 3, 4), ['Rachel Green']]
# [(5, 3, 4), ['notPresent']]
#
# [(5, 6, 7), ['Rachel Green']]
# [(5, 6, 7), ['5_3_4']]
#
# [(11, 7, 8), ['11_4_5']]
# [(11, 7, 8), ['notPresent']]
#
# [(12, 5, 6), ['Chandler Bing', 'Joey Tribbiani', 'Rachel Green']]
# [(12, 5, 6), ['notPresent']]
#
# [(12, 8, 9), ['Chandler Bing', 'Joey Tribbiani', 'Rachel Green']]
# [(12, 8, 9), ['notPresent']]
#
# [(17, 13, 14), ['notPresent']]
# [(17, 13, 14), ['Monica Geller']]
#
# [(17, 16, 19), ['notPresent']]
# [(17, 16, 19), ['17_5_8']]
#
# [(21, 6, 7), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(21, 6, 7), ['# ALL #']]
#
# [(21, 6, 8), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(21, 6, 8), ['# ALL #']]
#
# [(21, 8, 9), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(21, 8, 9), ['# ALL #']]
#
# [(22, 4, 5), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(22, 4, 5), ['# ALL #']]
#
# [(22, 4, 6), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(22, 4, 6), ['# ALL #']]
#
# [(22, 5, 6), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(22, 5, 6), ['# ALL #']]
#
# [(22, 7, 8), ['notPresent']]
# [(22, 7, 8), ['21_10_11']]
#
# [(22, 9, 10), ['notPresent']]
# [(22, 9, 10), ['22_7_8']]
#
# [(22, 12, 13), ['Chandler Bing', 'Joey Tribbiani', 'Monica Geller']]
# [(22, 12, 13), ['22_4_5']]
#
# [(23, 6, 8), ['23_4_5']]
# [(23, 6, 8), ['Joey Tribbiani']]
#
# [(27, 2, 3), ['notPresent']]
# [(27, 2, 3), ['26_7_16']]
#
# [(28, 2, 6), ['notPresent']]
# [(28, 2, 6), ['notMention']]
#
# [(28, 7, 8), ['notPresent']]
# [(28, 7, 8), ['Joey Tribbiani']]
#
# [(30, 11, 12), ['notPresent']]
# [(30, 11, 12), ['Chandler Bing']]
#
# [(30, 13, 20), ['30_11_12']]
# [(30, 13, 20), ['notMention']]
#
# [(30, 16, 20), ['notPresent']]
# [(30, 16, 20), ['30_11_12']]
#
# [(31, 4, 5), ['Chandler Bing', 'Monica Geller']]
# [(31, 4, 5), ['31_2_3']]
#
# [(34, 11, 15), ['Rachel Green']]
# [(34, 11, 15), ['notPresent']]
#
# [(36, 7, 8), ['36_4_5']]
# [(36, 7, 8), ['34_11_15']]
#
# [(40, 5, 7), ['notPresent']]
# [(40, 5, 7), ['notMention']]
#
# [(40, 9, 10), ['Monica Geller', 'Rachel Green']]
# [(40, 9, 10), ['40_2_3']]
#
# [(40, 27, 28), ['Paul the Wine Guy']]
# [(40, 27, 28), ['34_5_6']]
#
# [(40, 43, 44), ['notPresent']]
# [(40, 43, 44), ['40_21_22']]
#
# ====================================================================================================
# s01e01c11f
# [(4, 18, 19), ['notPresent']]
# [(4, 18, 19), ['2_4_5']]
#
# [(6, 12, 13), ['5_4_5']]
# [(6, 12, 13), ['6_2_3']]
#
# [(7, 11, 12), ['7_7_8']]
# [(7, 11, 12), ['6_12_13']]
#
# [(8, 8, 9), ['7_7_8']]
# [(8, 8, 9), ['7_11_12']]
#
# [(8, 18, 19), ['7_11_12']]
# [(8, 18, 19), ['6_12_13']]
#
# ====================================================================================================
# s07e18c11t
# [(0, 16, 17), ['Raj']]
# [(0, 16, 17), ['notPresent']]
#
# [(1, 11, 12), ['1_9_10']]
# [(1, 11, 12), ['notPresent']]
#
# [(2, 2, 3), ['notPresent']]
# [(2, 2, 3), ['0_16_18']]
#
# [(8, 11, 12), ['Amy', 'Bernadette', 'Leonard', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(8, 11, 12), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj']]
#
# [(8, 14, 15), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(8, 14, 15), ['8_11_12']]
#
# [(10, 11, 12), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(10, 11, 12), ['8_11_12']]
#
# [(10, 28, 30), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(10, 28, 30), ['notMention']]
#
# [(10, 28, 29), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(10, 28, 29), ['notMention']]
#
# [(10, 29, 30), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(10, 29, 30), ['8_11_12']]
#
# [(10, 50, 51), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(10, 50, 51), ['8_11_12']]
#
# [(12, 6, 7), ['notPresent']]
# [(12, 6, 7), ['10_8_9']]
#
# [(13, 3, 4), ['notPresent']]
# [(13, 3, 4), ['12_6_7']]
#
# [(17, 6, 7), ['Amy', 'Bernadette', 'Leonard', 'Penny', 'Raj', 'Stuart']]
# [(17, 6, 7), ['17_4_5']]
#
# [(18, 8, 9), ['Amy', 'Bernadette', 'Penny', 'Raj', 'Stuart']]
# [(18, 8, 9), ['17_6_7']]
#
# [(18, 8, 10), ['Amy', 'Bernadette', 'Penny', 'Raj', 'Stuart']]
# [(18, 8, 10), ['17_6_7']]
#
# [(18, 11, 13), ['notPresent']]
# [(18, 11, 13), ['10_38_43']]
#
# ====================================================================================================
# s01e01c12f
# [(0, 6, 8), ['0_4_5']]
# [(0, 6, 8), ['notPresent']]
#
# [(1, 8, 9), ['notPresent']]
# [(1, 8, 9), ['1_6_7']]
#
# [(2, 2, 3), ['Monica Geller', 'Ross Geller']]
# [(2, 2, 3), ['Joey Tribbiani', 'Monica Geller', 'Ross Geller']]
#
# [(2, 14, 15), ['notPresent']]
# [(2, 14, 15), ['Monica Geller']]
#
# [(3, 8, 9), ['notPresent']]
# [(3, 8, 9), ['3_4_5']]
#
# [(4, 12, 13), ['notPresent']]
# [(4, 12, 13), ['4_4_5']]
#
# [(5, 4, 5), ['5_3_4']]
# [(5, 4, 5), ['Monica Geller']]
#
# [(5, 7, 8), ['notPresent']]
# [(5, 7, 8), ['5_3_4']]
#
# [(7, 9, 10), ['Phoebe Buffay']]
# [(7, 9, 10), ['notPresent']]
#
# [(8, 10, 11), ['notPresent']]
# [(8, 10, 11), ['0_4_5']]
#
# [(8, 12, 14), ['8_10_11']]
# [(8, 12, 14), ['0_6_8']]
#
# [(15, 20, 25), ['notPresent']]
# [(15, 20, 25), ['notMention']]
#
# [(15, 24, 25), ['15_2_3']]
# [(15, 24, 25), ['13_9_13']]
#
# [(16, 7, 8), ['15_2_3']]
# [(16, 7, 8), ['13_9_13']]
#
# [(19, 2, 4), ['notPresent']]
# [(19, 2, 4), ['18_3_4']]
#
# ====================================================================================================
# s01e01c13f
# [(1, 7, 8), ['Rachel Green']]
# [(1, 7, 8), ['notPresent']]
#
# [(5, 16, 17), ['5_14_15']]
# [(5, 16, 17), ['notPresent']]
#
# [(5, 57, 58), ['5_47_50']]
# [(5, 57, 58), ['5_47_54']]
#
# [(8, 16, 17), ['Monica Geller']]
# [(8, 16, 17), ['notPresent']]
#
# [(13, 2, 15), ['notPresent']]
# [(13, 2, 15), ['notMention']]
#
# [(14, 2, 3), ['notPresent']]
# [(14, 2, 3), ['Rachel Green']]
#
# [(14, 4, 5), ['notPresent']]
# [(14, 4, 5), ['Rachel Green']]
#
# [(14, 9, 10), ['notPresent']]
# [(14, 9, 10), ['Rachel Green']]
#
# [(14, 11, 12), ['notPresent']]
# [(14, 11, 12), ['11_4_5']]
#
# [(14, 13, 14), ['notPresent']]
# [(14, 13, 14), ['Rachel Green']]
#
# [(14, 18, 19), ['notPresent']]
# [(14, 18, 19), ['notMention']]
#
# [(14, 20, 21), ['notPresent']]
# [(14, 20, 21), ['notMention']]
#
# [(14, 22, 23), ['notPresent']]
# [(14, 22, 23), ['notMention']]
#
# [(14, 24, 25), ['notPresent']]
# [(14, 24, 25), ['Rachel Green']]
#
# [(14, 26, 27), ['Monica Geller', 'Phoebe Buffay', 'Rachel Green', 'Ross Geller']]
# [(14, 26, 27), ['notPresent']]
#
# [(17, 7, 8), ['notPresent']]
# [(17, 7, 8), ['17_3_4']]
#
# [(18, 11, 12), ['Rachel Green']]
# [(18, 11, 12), ['17_3_4']]
#
# [(18, 16, 17), ['18_8_9']]
# [(18, 16, 17), ['18_4_7']]
#
# [(24, 2, 3), ['notPresent']]
# [(24, 2, 3), ['23_3_4']]
#
# [(24, 24, 26), ['notPresent']]
# [(24, 24, 26), ['notMention']]
#
# [(24, 27, 28), ['Chandler Bing', 'Phoebe Buffay', 'Rachel Green Ross Geller']]
# [(24, 27, 28), ['Chandler Bing', 'Monica Geller', 'Rachel Green', 'Ross Geller']]
#
# [(30, 3, 4), ['29_9_10']]
# [(30, 3, 4), ['29_3_4']]
#
# [(34, 11, 16), ['34_9_10']]
# [(34, 11, 16), ['notPresent']]
#
# [(41, 3, 4), ['Ross Geller']]
# [(41, 3, 4), ['notPresent']]
#
# ====================================================================================================
# s01e02c00f
# [(5, 5, 6), ['notPresent']]
# [(5, 5, 6), ['0_11_12']]
#
# [(5, 7, 25), ['notMention']]
# [(5, 7, 25), ['notPresent']]
#
# [(5, 12, 25), ['notPresent']]
# [(5, 12, 25), ['5_7_10']]
#
# [(6, 7, 8), ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']]
# [(6, 7, 8), ['5_3_4']]
#
# [(6, 11, 13), ['notPresent']]
# [(6, 11, 13), ['5_12_25']]
#
# [(6, 14, 15), ['notPresent']]
# [(6, 14, 15), ['6_3_4']]
#
# [(6, 18, 19), ['notPresent']]
# [(6, 18, 19), ['6_11_13']]
#
# [(6, 22, 23), ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']]
# [(6, 22, 23), ['5_3_4']]
#
# [(7, 14, 16), ['notPresent']]
# [(7, 14, 16), ['7_7_9']]
#
# [(7, 17, 19), ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']]
# [(7, 17, 19), ['0_9_10']]
#
# [(7, 17, 18), ['Monica Geller', 'Phoebe Buffay', 'Rachel Green']]
# [(7, 17, 18), ['0_9_10']]
#
# [(7, 23, 25), ['notPresent']]
# [(7, 23, 25), ['6_11_13']]
#
# [(7, 27, 28), ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']]
# [(7, 27, 28), ['5_3_4']]
#
# [(8, 10, 12), ['notPresent']]
# [(8, 10, 12), ['6_11_13']]
#
# [(8, 16, 17), ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']]
# [(8, 16, 17), ['Chandler Bing']]
#
# [(8, 19, 20), ['Chandler Bing', 'Joey Tribbiani', 'Ross Geller']]
# [(8, 19, 20), ['Chandler Bing']]
#
# [(9, 7, 8), ['notPresent']]
# [(9, 7, 8), ['0_19_20']]
#
# ====================================================================================================

# %%
print(disagreed_num)
print((all_num-disagreed_num)/all_num, (all_num-disagreed_num))
print(all_num)
print(union_num/all_num)
# Out:
# 460
# 0.7377423033067275 1294
# 1754
# 0.9908779931584949
