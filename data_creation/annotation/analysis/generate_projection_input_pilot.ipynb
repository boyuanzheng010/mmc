# %%
import csv
import json
from copy import deepcopy
import pickle as pkl

# %%
from utils.data_util import read_mturk_annotation_multiple_scene
from utils.data_util import read_turkle_annotation_multiple_scene
from utils.data_util import read_annotation
from utils.data_util import gather_by_scene

# %%
def collect_query_for_projection(answer_spans):
    # Collect all annotations
    annotations = []
    for x in answer_spans:
        query = x['querySpan']
        if x['notPresent']:
            antecedents = "notPresent"
        elif x['notMention']:
            antecedents = "notMention"
        else:
            antecedents = []
            for token in x['span_list']:
                if token['sentenceIndex']!=-1 and token['startToken']!=-1 and token['endToken']!=-1:
                    antecedents.append(token)
        annotations.append({
            "query": query,
            "antecedents": antecedents
        })
    return annotations

# %%
with open('data/all_scenes.pkl', 'rb') as f:
    all_scenes = pkl.load(f)

data = read_mturk_annotation_multiple_scene('data/bulk_0/results.csv')
results = []
results.extend(data)

output = []
for item in results:
    temp = {
        "sentences": item['sentences'],
    }
    annotations = collect_query_for_projection(item['answer_spans'])
    temp["annotations"] = annotations
    temp['zh_subtitles'] = all_scenes[item['scene_id']]['zh_subtitles']
    temp['fa_subtitles'] = all_scenes[item['scene_id']]['fa_subtitles']
    temp["scene_id"] = item['scene_id']
    output.append(temp)

with open('annotation_results_bulk_0.json', 'w') as f:
    json.dump(output, f)

# %%
mturk_2 = read_mturk_annotation_multiple_scene('data/pilot_2/golden.csv')
# mturk_3 = read_mturk_annotation_multiple_scene('data/pilot_1/pilot_1.csv')
# mturk_4 = read_mturk_annotation_multiple_scene('data/pilot_1/pilot_2.csv')

results = []
results.extend(mturk_2)
# results.extend(mturk_3)
# results.extend(mturk_4)

scenes = gather_by_scene(results)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/w9/673mfrb56v7dvx7hhvw7s6240000gn/T/ipykernel_69960/2058562220.py in <module>
# ----> 1 mturk_2 = read_mturk_annotation_multiple_scene('data/pilot_2/golden.csv')
#       2 # mturk_3 = read_mturk_annotation_multiple_scene('data/pilot_1/pilot_1.csv')
#       3 # mturk_4 = read_mturk_annotation_multiple_scene('data/pilot_1/pilot_2.csv')
#       4
#       5 results = []
#
# ~/PycharmProjects/multi_coref/annotation/analysis/utils/data_util.py in read_mturk_annotation_multiple_scene(path)
#     385             sentence_offsets = inputs['sentence_offsets']
#     386             query_spans_offsets = inputs['querySpans_offsets']
# --> 387             scene_ids = inputs['scene_ids']
#     388
#     389             all_answer_spans = json.loads(instance["Answer.answer_spans"])
#
# KeyError: 'scene_ids'

# %%
output = {}
for i, scene_id in enumerate(scenes):
    scene = scenes[scene_id]
    temp = {"sentences": scene[0]['sentences']}
    for j, item in enumerate(scene):
        annotations = collect_query_for_projection(item['answer_spans'])
        temp["annotations_" + str(j)] = annotations
    output["scene_"+str(i)] = temp

with open('annotation_results.json', 'w') as f:
    json.dump(output, f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/w9/673mfrb56v7dvx7hhvw7s6240000gn/T/ipykernel_28992/4264548308.py in <module>
#       2 for i, scene_id in enumerate(scenes):
#       3     scene = [scenes[scene_id]]
# ----> 4     temp = {"sentences": scene[0]['sentences']}
#       5     for j, item in enumerate(scene):
#       6         annotations = collect_query_for_projection(item['answer_spans'])
#
# TypeError: list indices must be integers or slices, not str

# %%
print(output)
# Out:
# {'scene_0': {'sentences': [['Penny', ':', 'Where', "'d", 'you', 'go', '?', 'I', 'ca', "n't", 'tell', 'if', 'the', 'turkey', "'s", 'done', '!'], ['Leonard', ':', 'Be', 'right', 'there', '!', 'Hi', ',', 'lover', '.'], ['Penny', ':', 'What', 'are', 'you', 'doing', '?'], ['Leonard', ':', 'I', "'", 'm', 'sorry', 'about', 'the', 'journal', '.', 'I', 'want', 'to', 'make', 'it', 'up', 'to', 'you', '.', 'So', 'I', "'", 'm', 'gon', 'na', 'let', 'you', 'post', 'a', 'shame', 'photo', 'of', 'me', 'on', 'Facebook', '.'], ['Penny', ':', 'I', 'am', 'not', 'putting', 'that', 'on', 'the', 'Internet', '!', 'I', 'do', "n't", 'want', 'people', 'to', 'see', 'this', '.', 'I', 'do', "n't", 'want', 'to', 'see', 'it', '!'], ['Leonard', ':', 'Do', "n't", 'want', 'people', 'to', 'see', 'what', ',', 'huh', '?', 'A', 'little', 'bit', 'of', 'this', '?'], ['Penny', ':', 'Oh', '.'], ['Leonard', ':', 'Some', 'of', 'this', '?', 'And', ',', 'since', 'it', "'s", 'Thanksgiving', ',', 'an', 'extra', 'helping', 'of', 'this', '?'], ['Bernadette', ':', 'Happy', 'Thanks', '…', 'Yikes', '.']], 'annotations_0': [{'query': {'sentenceIndex': 0, 'startToken': 4, 'endToken': 5}, 'antecedents': []}, {'query': {'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}, 'antecedents': [{'sentenceIndex': 0, 'startToken': 0, 'endToken': 1}]}, {'query': {'sentenceIndex': 0, 'startToken': 12, 'endToken': 14}, 'antecedents': []}, {'query': {'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}, 'antecedents': [{'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}]}, {'query': {'sentenceIndex': 2, 'startToken': 2, 'endToken': 3}, 'antecedents': []}, {'query': {'sentenceIndex': 2, 'startToken': 4, 'endToken': 5}, 'antecedents': [{'sentenceIndex': 0, 'startToken': 4, 'endToken': 5}]}, {'query': {'sentenceIndex': 3, 'startToken': 2, 'endToken': 3}, 'antecedents': [{'sentenceIndex': 2, 'startToken': 4, 'endToken': 5}]}, {'query': {'sentenceIndex': 3, 'startToken': 4, 'endToken': 9}, 'antecedents': []}, {'query': {'sentenceIndex': 3, 'startToken': 10, 'endToken': 11}, 'antecedents': [{'sentenceIndex': 2, 'startToken': 4, 'endToken': 5}]}, {'query': {'sentenceIndex': 3, 'startToken': 14, 'endToken': 15}, 'antecedents': []}, {'query': {'sentenceIndex': 3, 'startToken': 17, 'endToken': 18}, 'antecedents': [{'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}]}, {'query': {'sentenceIndex': 3, 'startToken': 20, 'endToken': 21}, 'antecedents': [{'sentenceIndex': 2, 'startToken': 4, 'endToken': 5}]}, {'query': {'sentenceIndex': 3, 'startToken': 26, 'endToken': 27}, 'antecedents': [{'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}]}, {'query': {'sentenceIndex': 3, 'startToken': 28, 'endToken': 31}, 'antecedents': []}, {'query': {'sentenceIndex': 3, 'startToken': 32, 'endToken': 33}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 10, 'endToken': 11}]}, {'query': {'sentenceIndex': 3, 'startToken': 34, 'endToken': 35}, 'antecedents': []}, {'query': {'sentenceIndex': 4, 'startToken': 2, 'endToken': 3}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 17, 'endToken': 18}]}, {'query': {'sentenceIndex': 4, 'startToken': 6, 'endToken': 7}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 28, 'endToken': 31}]}, {'query': {'sentenceIndex': 4, 'startToken': 8, 'endToken': 10}, 'antecedents': []}, {'query': {'sentenceIndex': 4, 'startToken': 11, 'endToken': 12}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 26, 'endToken': 27}]}, {'query': {'sentenceIndex': 4, 'startToken': 15, 'endToken': 16}, 'antecedents': []}, {'query': {'sentenceIndex': 4, 'startToken': 18, 'endToken': 19}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 28, 'endToken': 31}]}, {'query': {'sentenceIndex': 4, 'startToken': 20, 'endToken': 21}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 26, 'endToken': 27}]}, {'query': {'sentenceIndex': 4, 'startToken': 26, 'endToken': 27}, 'antecedents': [{'sentenceIndex': 3, 'startToken': 28, 'endToken': 31}]}, {'query': {'sentenceIndex': 5, 'startToken': 5, 'endToken': 6}, 'antecedents ...

# %%
golden = read_turkle_annotation_multiple_scene('data/pilot_2/golden.csv')
for item in golden:
    item['WorkerId'] = "golden"

results = []
results.extend(golden)

scenes = gather_by_scene(results)

# %%
output = {}
for i, item in enumerate(golden):
    temp = {"sentences": item['sentences']}

    # Collect all annotations
    annotations = []
    answer_spans = item['answer_spans']
    for x in answer_spans:
        query = x['querySpan']
        antecedents = []
        for token in x['span_list']:
            if token['sentenceIndex']!=-1 and token['startToken']!=-1 and token['endToken']!=-1:
                antecedents.append(token)
        annotations.append({
            "query": query,
            "antecedents": antecedents
        })
    temp['annotations'] = annotations

    # Collect speaker queries and non-speaker queries
    all_speakers = set([sent[0] for sent in item['sentences']])
    all_speaker_mentions = []
    for cluster in item['clusters_all']:
        for speaker in all_speakers:
            if tuple([speaker]) in cluster:
                all_speaker_mentions.extend(cluster)
    # print(all_speaker_mentions)
    speaker_annotations = []
    non_speaker_annotations = []
    for x in answer_spans:
        query = x['querySpan']
        antecedents = []
        for token in x['span_list']:
            if token['sentenceIndex']!=-1 and token['startToken']!=-1 and token['endToken']!=-1:
                antecedents.append(token)
        query_key = tuple(["_".join([str(query['sentenceIndex']), str(query['startToken']), str(query['endToken'])])])
        if query_key in all_speaker_mentions:
            speaker_annotations.append({
            "query": query,
            "antecedents": antecedents
            })
        else:
            non_speaker_annotations.append({
            "query": query,
            "antecedents": antecedents
            })
    temp['speaker_annotations'] = speaker_annotations
    temp['non_speaker_annotations'] = non_speaker_annotations

    output["scene_"+str(i)] = temp

with open('annotation_results.json', 'w') as f:
    json.dump(output, f)

# %%
print(scenes.keys())
# Out:
# dict_keys([":|Where|'d|you|go|?|I|ca|n't", ':|Oh|,|yeah|,|no|,|this|thing', ':|We|just|wanted|to|see|how|your|class'])

# %%
print(scenes)
# Out:
# {":|Where|'d|you|go|?|I|ca|n't": [{'sentences': [['Penny', ':', 'Where', "'d", 'you', 'go', '?', 'I', 'ca', "n't", 'tell', 'if', 'the', 'turkey', "'s", 'done', '!'], ['Leonard', ':', 'Be', 'right', 'there', '!', 'Hi', ',', 'lover', '.'], ['Penny', ':', 'What', 'are', 'you', 'doing', '?'], ['Leonard', ':', 'I', "'", 'm', 'sorry', 'about', 'the', 'journal', '.', 'I', 'want', 'to', 'make', 'it', 'up', 'to', 'you', '.', 'So', 'I', "'", 'm', 'gon', 'na', 'let', 'you', 'post', 'a', 'shame', 'photo', 'of', 'me', 'on', 'Facebook', '.'], ['Penny', ':', 'I', 'am', 'not', 'putting', 'that', 'on', 'the', 'Internet', '!', 'I', 'do', "n't", 'want', 'people', 'to', 'see', 'this', '.', 'I', 'do', "n't", 'want', 'to', 'see', 'it', '!'], ['Leonard', ':', 'Do', "n't", 'want', 'people', 'to', 'see', 'what', ',', 'huh', '?', 'A', 'little', 'bit', 'of', 'this', '?'], ['Penny', ':', 'Oh', '.'], ['Leonard', ':', 'Some', 'of', 'this', '?', 'And', ',', 'since', 'it', "'s", 'Thanksgiving', ',', 'an', 'extra', 'helping', 'of', 'this', '?'], ['Bernadette', ':', 'Happy', 'Thanks', '…', 'Yikes', '.']], 'query_spans': [{'sentenceIndex': 0, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}, {'sentenceIndex': 0, 'startToken': 12, 'endToken': 14}, {'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}, {'sentenceIndex': 2, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 2, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 3, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 3, 'startToken': 4, 'endToken': 9}, {'sentenceIndex': 3, 'startToken': 10, 'endToken': 11}, {'sentenceIndex': 3, 'startToken': 14, 'endToken': 15}, {'sentenceIndex': 3, 'startToken': 17, 'endToken': 18}, {'sentenceIndex': 3, 'startToken': 20, 'endToken': 21}, {'sentenceIndex': 3, 'startToken': 26, 'endToken': 27}, {'sentenceIndex': 3, 'startToken': 28, 'endToken': 31}, {'sentenceIndex': 3, 'startToken': 32, 'endToken': 33}, {'sentenceIndex': 3, 'startToken': 34, 'endToken': 35}, {'sentenceIndex': 4, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 4, 'startToken': 6, 'endToken': 7}, {'sentenceIndex': 4, 'startToken': 8, 'endToken': 10}, {'sentenceIndex': 4, 'startToken': 11, 'endToken': 12}, {'sentenceIndex': 4, 'startToken': 15, 'endToken': 16}, {'sentenceIndex': 4, 'startToken': 18, 'endToken': 19}, {'sentenceIndex': 4, 'startToken': 20, 'endToken': 21}, {'sentenceIndex': 4, 'startToken': 26, 'endToken': 27}, {'sentenceIndex': 5, 'startToken': 5, 'endToken': 6}, {'sentenceIndex': 5, 'startToken': 8, 'endToken': 15}, {'sentenceIndex': 5, 'startToken': 8, 'endToken': 9}, {'sentenceIndex': 5, 'startToken': 16, 'endToken': 17}, {'sentenceIndex': 7, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 7, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 7, 'startToken': 9, 'endToken': 10}, {'sentenceIndex': 7, 'startToken': 11, 'endToken': 12}, {'sentenceIndex': 7, 'startToken': 13, 'endToken': 16}, {'sentenceIndex': 7, 'startToken': 17, 'endToken': 18}, {'sentenceIndex': 8, 'startToken': 2, 'endToken': 4}, {'sentenceIndex': 8, 'startToken': 5, 'endToken': 6}], 'answer_spans': [{'querySpan': {'sentenceIndex': 0, 'startToken': 4, 'endToken': 5}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 0, 'startToken': 0, 'endToken': 1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 0, 'startToken': 12, 'endToken': 14}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 0, 'startTo ...

# %%
output = {}
for i, scene_id in enumerate(scenes):
    print(scenes[scene_id])

    print("scene_" + str(i), scene_id)
    output["scene_" + str(i)] = []
# Out:
# [{'sentences': [['Penny', ':', 'Where', "'d", 'you', 'go', '?', 'I', 'ca', "n't", 'tell', 'if', 'the', 'turkey', "'s", 'done', '!'], ['Leonard', ':', 'Be', 'right', 'there', '!', 'Hi', ',', 'lover', '.'], ['Penny', ':', 'What', 'are', 'you', 'doing', '?'], ['Leonard', ':', 'I', "'", 'm', 'sorry', 'about', 'the', 'journal', '.', 'I', 'want', 'to', 'make', 'it', 'up', 'to', 'you', '.', 'So', 'I', "'", 'm', 'gon', 'na', 'let', 'you', 'post', 'a', 'shame', 'photo', 'of', 'me', 'on', 'Facebook', '.'], ['Penny', ':', 'I', 'am', 'not', 'putting', 'that', 'on', 'the', 'Internet', '!', 'I', 'do', "n't", 'want', 'people', 'to', 'see', 'this', '.', 'I', 'do', "n't", 'want', 'to', 'see', 'it', '!'], ['Leonard', ':', 'Do', "n't", 'want', 'people', 'to', 'see', 'what', ',', 'huh', '?', 'A', 'little', 'bit', 'of', 'this', '?'], ['Penny', ':', 'Oh', '.'], ['Leonard', ':', 'Some', 'of', 'this', '?', 'And', ',', 'since', 'it', "'s", 'Thanksgiving', ',', 'an', 'extra', 'helping', 'of', 'this', '?'], ['Bernadette', ':', 'Happy', 'Thanks', '…', 'Yikes', '.']], 'query_spans': [{'sentenceIndex': 0, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}, {'sentenceIndex': 0, 'startToken': 12, 'endToken': 14}, {'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}, {'sentenceIndex': 2, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 2, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 3, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 3, 'startToken': 4, 'endToken': 9}, {'sentenceIndex': 3, 'startToken': 10, 'endToken': 11}, {'sentenceIndex': 3, 'startToken': 14, 'endToken': 15}, {'sentenceIndex': 3, 'startToken': 17, 'endToken': 18}, {'sentenceIndex': 3, 'startToken': 20, 'endToken': 21}, {'sentenceIndex': 3, 'startToken': 26, 'endToken': 27}, {'sentenceIndex': 3, 'startToken': 28, 'endToken': 31}, {'sentenceIndex': 3, 'startToken': 32, 'endToken': 33}, {'sentenceIndex': 3, 'startToken': 34, 'endToken': 35}, {'sentenceIndex': 4, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 4, 'startToken': 6, 'endToken': 7}, {'sentenceIndex': 4, 'startToken': 8, 'endToken': 10}, {'sentenceIndex': 4, 'startToken': 11, 'endToken': 12}, {'sentenceIndex': 4, 'startToken': 15, 'endToken': 16}, {'sentenceIndex': 4, 'startToken': 18, 'endToken': 19}, {'sentenceIndex': 4, 'startToken': 20, 'endToken': 21}, {'sentenceIndex': 4, 'startToken': 26, 'endToken': 27}, {'sentenceIndex': 5, 'startToken': 5, 'endToken': 6}, {'sentenceIndex': 5, 'startToken': 8, 'endToken': 15}, {'sentenceIndex': 5, 'startToken': 8, 'endToken': 9}, {'sentenceIndex': 5, 'startToken': 16, 'endToken': 17}, {'sentenceIndex': 7, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 7, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 7, 'startToken': 9, 'endToken': 10}, {'sentenceIndex': 7, 'startToken': 11, 'endToken': 12}, {'sentenceIndex': 7, 'startToken': 13, 'endToken': 16}, {'sentenceIndex': 7, 'startToken': 17, 'endToken': 18}, {'sentenceIndex': 8, 'startToken': 2, 'endToken': 4}, {'sentenceIndex': 8, 'startToken': 5, 'endToken': 6}], 'answer_spans': [{'querySpan': {'sentenceIndex': 0, 'startToken': 4, 'endToken': 5}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 0, 'startToken': 0, 'endToken': 1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 0, 'startToken': 12, 'endToken': 14}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 1, 'startToken': 8, 'endToken': 9}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 0, 'startToken': 7, 'endToken': 8}], 'curren ...
# scene_0 :|Where|'d|you|go|?|I|ca|n't
# [{'sentences': [['Penny', ':', 'Oh', ',', 'yeah', ',', 'no', ',', 'this', 'thing', "'s", 'majorly', 'out', 'of', 'order', '.', 'See', '?'], ['Ramona', ':', 'Sorry', '.', 'That', "'s", 'okay', '.', 'Guess', 'I', "'", 'm', 'taking', 'the', 'stairs', '.'], ['Penny', ':', 'Where', 'you', 'going', '?'], ['Ramona', ':', '4', '-', 'A.'], ['Penny', ':', 'Oh', ',', 'are', 'you', 'here', 'to', 'see', 'Leonard', '?'], ['Ramona', ':', 'No', ',', 'Dr.', 'Cooper', '.'], ['Penny', ':', 'Dr.', 'Sheldon', 'Cooper', '?'], ['Ramona', ':', 'We', "'re", 'having', 'dinner', '.'], ['Penny', ':', 'Sheldon', 'Cooper', '?', 'Tall', ',', 'thin', ',', 'looks', 'a', 'little', 'like', 'a', 'giant', 'praying', 'mantis', '?'], ['Ramona', ':', 'He', 'is', 'cute', ',', 'is', "n't", 'he', '?'], ['Penny', ':', 'Sheldon', 'Cooper', '?']], 'query_spans': [{'sentenceIndex': 0, 'startToken': 8, 'endToken': 10}, {'sentenceIndex': 0, 'startToken': 14, 'endToken': 15}, {'sentenceIndex': 1, 'startToken': 4, 'endToken': 5}, {'sentenceIndex': 1, 'startToken': 9, 'endToken': 10}, {'sentenceIndex': 1, 'startToken': 13, 'endToken': 15}, {'sentenceIndex': 2, 'startToken': 3, 'endToken': 4}, {'sentenceIndex': 3, 'startToken': 2, 'endToken': 5}, {'sentenceIndex': 4, 'startToken': 5, 'endToken': 6}, {'sentenceIndex': 4, 'startToken': 9, 'endToken': 10}, {'sentenceIndex': 5, 'startToken': 2, 'endToken': 6}, {'sentenceIndex': 6, 'startToken': 2, 'endToken': 5}, {'sentenceIndex': 7, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 7, 'startToken': 5, 'endToken': 6}, {'sentenceIndex': 8, 'startToken': 2, 'endToken': 4}, {'sentenceIndex': 8, 'startToken': 13, 'endToken': 17}, {'sentenceIndex': 9, 'startToken': 2, 'endToken': 3}, {'sentenceIndex': 9, 'startToken': 8, 'endToken': 9}, {'sentenceIndex': 10, 'startToken': 2, 'endToken': 4}], 'answer_spans': [{'querySpan': {'sentenceIndex': 0, 'startToken': 8, 'endToken': 10}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 0, 'startToken': 14, 'endToken': 15}, 'notPresent': False, 'notMention': True, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 1, 'startToken': 4, 'endToken': 5}, 'notPresent': False, 'notMention': True, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 1, 'startToken': 9, 'endToken': 10}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 1, 'startToken': 0, 'endToken': 1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 1, 'startToken': 13, 'endToken': 15}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 2, 'startToken': 3, 'endToken': 4}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 1, 'startToken': 9, 'endToken': 10}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 3, 'startToken': 2, 'endToken': 5}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 4, 'startToken': 5, 'endToken': 6}, 'notPresent': False, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': 2, 'startToken': 3, 'endToken': 4}], 'currentAnswerIndex': 0, 'status': 'ok'}, {'querySpan': {'sentenceIndex': 4, 'startToken': 9, 'endToken': 10}, 'notPresent': True, 'notMention': False, 'notSure': False, 'span_list': [{'sentenceIndex': -1, 'startToken': -1, 'endToken': -1}], 'currentAnswerIndex': 0, 'status': 'ok'}, ...
# scene_1 :|Oh|,|yeah|,|no|,|this|thing
# [{'sentences': [['Leonard', ':', 'We', 'just', 'wanted', 'to', 'see', 'how', 'your', 'class', 'was', 'going', '.', 'Where', 'is', 'everybody', '?'], ['Sheldon', ':', 'There', 'is', 'no', 'class', '.'], ['Howard', ':', 'Did', 'you', 'send', 'everyone', 'to', 'the', 'principal', "'s", 'office', 'already', '?'], ['Sheldon', ':', 'No', 'one', 'signed', 'up', '.'], ['Leonard', ':', 'Well', ',', 'that', "'s", 'not', 'your', 'fault', '.'], ['Sheldon', ':', 'I', 'called', 'the', 'department', 'secretary', 'to', 'see', 'what', 'happened', '.', 'Apparently', ',', 'I', 'have', 'a', 'reputation', 'for', 'being', 'obnoxious', '.', 'What', '?'], ['Leonard', ':', 'What', '?'], ['Raj', ':', 'Hey', ',', 'Sheldon', ',', 'I', "'", 'm', 'sorry', '.'], ['Sheldon', ':', 'No', ',', 'it', "'s", 'fine', '.', 'Now', 'I', 'can', 'devote', 'all', 'my', 'time', 'to', 'dark', 'matter', '.'], ['Raj', ':', 'Aw', ',', 'you', 'brought', 'cookies', 'for', 'everyone', '?'], ['Sheldon', ':', 'Oh', ',', 'yes', '.', 'Fig', 'Newtons', '.', 'which', 'scientist', 'both', 'helped', 'to', 'develop', 'calculus', 'and', 'had', 'a', 'famous', 'cookie', 'named', 'after', 'him', '?', 'And', 'then', 'after', 'someone', 'said', '"', 'Newton', ',', '"', 'I', 'was', 'going', 'to', 'tell', 'them', 'they', "'re", 'wrong', '.', 'The', 'cookies', 'are', 'named', 'after', 'a', 'town', 'in', 'Massachusetts', '.', 'And', 'then', 'I', "'d", 'throw', 'the', 'cookies', 'away', '.'], ['Howard', ':', 'Hey', ',', 'what', 'if', 'I', 'took', 'your', 'class', '?'], ['Sheldon', ':', 'Why', 'would', 'you', 'do', 'that', '?'], ['Leonard', ':', 'Why', 'would', 'you', 'do', 'that', '?', 'Yeah', ',', 'why', 'would', 'you', 'do', 'that', '?'], ['Raj', ':', 'What', '’s', 'wrong', 'with', 'you', '?'], ['Howard', ':', 'I', "'", 'm', 'thinking', 'about', 'getting', 'my', 'doctorate', ',', 'and', 'he', 'wants', 'to', 'teach--', 'why', 'not', '?'], ['Sheldon', ':', 'Oh', ',', 'Howard', '.', 'I', 'appreciate', 'the', 'gesture', ',', 'but', 'this', 'is', 'a', 'graduate', '-', 'level', 'physics', 'class', '.', 'I', 'do', "n't", 'think', 'you', "'d", 'understand', 'a', 'single', 'thing', 'I', 'was', 'talking', 'about', '.'], ['Raj', ':', 'Ask', 'why', 'not', 'again', ';'], ['Howard', ':', 'Sheldon', ',', 'I', "'", 'm', 'more', 'than', 'smart', 'enough', 'to', 'take', 'your', 'class', '.', 'No', '.'], ['Sheldon', ':', 'No', '.'], ['Howard', ':', 'Yes', '.'], ['Sheldon', ':', 'How', 'would', 'you', 'determine', 'the', 'ground', 'state', 'of', 'a', 'quantum', 'system', 'with', 'no', 'exact', 'solution', '?'], ['Howard', ':', 'I', 'would', 'guess', 'a', 'wave', '-', 'function', 'and', 'then', 'vary', 'its', 'parameters', 'until', 'I', 'found', 'the', 'lowest', 'energy', 'solution', '.'], ['Sheldon', ':', 'Do', 'you', 'know', 'how', 'to', 'integrate', 'X', 'squared', 'times', 'E', 'to', 'the', 'minus', 'X', ',', 'without', 'looking', 'it', 'up', '?'], ['Howard', ':', 'I', "'d", 'use', 'Feynman', "'s", 'trick--', 'differentiate', 'under', 'the', 'integral', 'sign', '.'], ['Sheldon', ':', 'Okay', '.', 'Um', '...', 'What', 'is', 'the', 'correct', 'interpretation', 'of', 'quantum', 'mechanics', '?'], ['Howard', ':', 'Since', 'every', 'interpretation', 'gives', 'exactly', 'the', 'same', 'answer', 'to', 'every', 'measurement', ',', 'they', 'are', 'all', 'equally', 'correct', '.', 'However', ',', 'I', 'know', 'you', 'believe', 'in', 'the', 'Many', 'Worlds', 'Interpretation', ',', 'so', 'I', "'ll", 'say', 'that', '.', 'Now', 'do', 'you', 'think', 'I', "'", 'm', 'smart', 'enough', '?'], ['Sheldon', ':', 'No', '.'], ['Howard', ':', 'Oh', ',', 'come', 'on', '.', 'You', 'might', "'", 've', 'gone', 'to', 'school', 'for', 'a', 'couple', 'more', 'years', 'than', 'me', ',', 'but', 'guess', 'what--', 'engineers', 'are', 'just', 'as', 'smart', 'as', 'physicists', '.'], ['Sheldon', ':', 'You', 'take', 'that', 'back', '!'], ['Howard', ':', 'No', '.']], 'query_spans': [{'sentenceIndex': 0, 'startToken': 2, 'endToken': 3}, {'sentenceInde ...
# scene_2 :|We|just|wanted|to|see|how|your|class

# %%
print(output)
# Out:
# {'scene_0': [], 'scene_1': [], 'scene_2': []}
