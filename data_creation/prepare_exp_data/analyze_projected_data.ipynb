# %%
import pickle as pkl
from copy import deepcopy
import jsonlines
from utils.my_util import cluster_mentions, remove_speaker_prefix
import json

# %%
with open('data/raw_source/dialogue_zh/all_coref_data_en_zh.json', 'r') as f:
    old_data = json.load(f)
with open('data/raw_source/dialogue_zh/all_coref_data_en_zh_with_id.json', 'r') as f:
    new_data = json.load(f)

# %%
print(len(old_data), len(new_data))
# Out:
# 1526 1526

# %%
for i in range(len(old_data)):
    if len(old_data[i]['sentences'])==len(new_data[i]['sentences']):
        continue
    print(old_data[i]['scene_id'])
    print(len(old_data[i]['sentences']), len(new_data[i]['sentences']))
    print()

# %%
old_data = []
with open('data/experiment_inputs/dialogue_chinese/train.chinese.512.jsonlines', 'r') as f:
    reader = jsonlines.Reader(f)
    for item in reader:
        old_data.append(item)

new_data = []
with open('data/experiment_inputs/dialogue_broken_chain_fixed_chinese/train.chinese.512.jsonlines', 'r') as f:
    reader = jsonlines.Reader(f)
    for item in reader:
        new_data.append(item)

# %%
for i in range(len(old_data)):
    # if i != 1:
    #     continue
    print(max(old_data[i]['sentence_map'])+1)
    print(max(new_data[i]['sentence_map'])+1)
    # print(len(old_data['sentences']), len(new_data['sentences']))
# Out:
# 23
# 23
# 36
# 36
# 8
# 8
# 17
# 17
# 5
# 5
# 13
# 13
# 7
# 7
# 3
# 3
# 9
# 9
# 17
# 17
# 25
# 25
# 27
# 27
# 37
# 37
# 23
# 23
# 16
# 16
# 3
# 3
# 16
# 16
# 16
# 16
# 32
# 32
# 31
# 31
# 13
# 13
# 16
# 16
# 13
# 13
# 4
# 4
# 16
# 16
# 15
# 15
# 11
# 11
# 10
# 10
# 14
# 14
# 22
# 22
# 26
# 26
# 14
# 14
# 3
# 3
# 14
# 14
# 53
# 53
# 8
# 8
# 25
# 25
# 23
# 23
# 15
# 15
# 19
# 19
# 19
# 19
# 66
# 66
# 50
# 50
# 29
# 29
# 32
# 32
# 19
# 19
# 25
# 25
# 35
# 35
# 33
# 33
# 29
# 29
# 15
# 15
# 15
# 15
# 30
# 30
# 21
# 21
# 14
# 14
# 31
# 31
# 19
# 19
# 5
# 5
# 9
# 9
# 32
# 32
# 42
# 42
# 21
# 21
# 17
# 17
# 22
# 22
# 30
# 30
# 17
# 17
# 15
# 15
# 17
# 17
# 11
# 11
# 12
# 12
# 27
# 27
# 8
# 8
# 25
# 25
# 14
# 14
# 24
# 24
# 19
# 19
# 53
# 53
# 23
# 23
# 2
# 2
# 11
# 11
# 22
# 22
# 38
# 38
# 54
# 54
# 29
# 29
# 20
# 20
# 19
# 19
# 41
# 41
# 17
# 17
# 24
# 24
# 15
# 15
# 2
# 2
# 28
# 28
# 28
# 28
# 23
# 23
# 9
# 9
# 10
# 10
# 30
# 30
# 8
# 8
# 7
# 7
# 34
# 34
# 16
# 16
# 33
# 33
# 55
# 55
# ...

# %%
print(len(old_data), len(new_data))
# Out:
# 948 946

# %%
old_ids = set()
new_ids = set()
for item in old_data:
    old_ids.add(item['doc_key'])
for item in new_data:
    new_ids.add(item['doc_key'])

# %%
print(old_ids)
# Out:
# {'s04e21c04t0_4', 's06e17c06t0_6', 's06e03c00t0_0', 's01e06c03f0_3', 's06e16c10t0_10', 's04e08c00t0_0', 's06e09c01t0_1', 's08e16c09t0_9', 's02e04c02t0_2', 's01e24c03f0_3', 's08e15c05t0_5', 's01e07c16f0_16', 's06e02c07t0_7', 's04e19c10t0_10', 's06e16c11t0_11', 's01e16c06t0_6', 's08e24c01t0_1', 's08e20c08t0_8', 's06e07c04t0_4', 's04e05c08t0_8', 's01e07c02f0_2', 's04e03c09t0_9', 's08e03c04t0_4', 's06e19c02t0_2', 's08e19c01t0_1', 's06e04c08t0_8', 's01e12c13f0_13', 's05e06c09t0_9', 's05e14c02t0_2', 's06e08c08t0_8', 's08e06c00t0_0', 's08e16c07t0_7', 's01e08c09f0_9', 's01e16c14f0_14', 's08e11c10t0_10', 's04e04c02t0_2', 's01e19c02f0_2', 's08e03c06t0_6', 's05e12c03t0_3', 's05e14c09t0_9', 's08e18c03t0_3', 's01e09c02f0_2', 's07e20c01t0_1', 's02e04c04t0_4', 's07e20c12t0_12', 's08e16c04t0_4', 's01e15c07t0_7', 's08e18c04t0_4', 's01e13c03t0_3', 's01e11c03t0_3', 's04e03c05t0_5', 's08e11c02t0_2', 's06e06c07t0_7', 's06e05c05t0_5', 's01e11c08t0_8', 's05e20c03t0_3', 's05e06c08t0_8', 's07e22c00t0_0', 's0
# ...

# %%
print(new_ids)
# Out:
# {'s04e21c04t0_4', 's06e17c06t0_6', 's06e03c00t0_0', 's01e06c03f0_3', 's06e16c10t0_10', 's04e08c00t0_0', 's06e09c01t0_1', 's08e16c09t0_9', 's02e04c02t0_2', 's01e24c03f0_3', 's08e15c05t0_5', 's01e07c16f0_16', 's06e02c07t0_7', 's04e19c10t0_10', 's06e16c11t0_11', 's01e16c06t0_6', 's08e24c01t0_1', 's08e20c08t0_8', 's06e07c04t0_4', 's04e05c08t0_8', 's01e07c02f0_2', 's04e03c09t0_9', 's08e03c04t0_4', 's06e19c02t0_2', 's08e19c01t0_1', 's06e04c08t0_8', 's01e12c13f0_13', 's05e06c09t0_9', 's05e14c02t0_2', 's06e08c08t0_8', 's08e06c00t0_0', 's08e16c07t0_7', 's01e08c09f0_9', 's01e16c14f0_14', 's08e11c10t0_10', 's04e04c02t0_2', 's01e19c02f0_2', 's08e03c06t0_6', 's05e12c03t0_3', 's05e14c09t0_9', 's08e18c03t0_3', 's01e09c02f0_2', 's07e20c01t0_1', 's02e04c04t0_4', 's07e20c12t0_12', 's08e16c04t0_4', 's01e15c07t0_7', 's08e18c04t0_4', 's01e13c03t0_3', 's01e11c03t0_3', 's04e03c05t0_5', 's08e11c02t0_2', 's06e06c07t0_7', 's06e05c05t0_5', 's01e11c08t0_8', 's05e20c03t0_3', 's05e06c08t0_8', 's07e22c00t0_0', 's0
# ...

# %%
print(old_ids-new_ids)
# Out:
# {'s06e15c00t0_0', 's05e14c00t0_0'}

# %%
for item in old_data:
    if item['doc_key'] in ['s06e15c00t0_0', 's05e14c00t0_0']:
        print(item)
        print()
# Out:
# {'doc_key': 's05e14c00t0_0', 'tokens': ['大家', '好', '我', '是', '谢尔顿', '・', '库珀', '博士', '欢迎', '收看', '由', '谢尔顿', '・', '库珀', '出品', '的', '《', '有趣', '的', '旗帜', '》', '之', '首播', '集在', '接下来', '的', '五十二', '周', '我们', '将', '一起', '探索', '旗帜', '学', '的', '奇妙', '世界', '等', '一下', '库', '博士', '旗帜', '学是', '什么', '旗帜', '学', '就是', '研究', '旗帜', '的', '我', '想', '我', '又', '长见识了', '你', '觉得', '有趣', '吗', '-', '当然', '这个', '节目', '具有', '两面性', '趣味性', '和', '知识性', '就', '如同', '这', '面', '两面', '的', '州', '旗', '一面', '是', '俄勒冈', '洲', '俄勒冈州', '该州', '以喜', '栖息', '于', '水边', '挖穴', '而', '居', '的', '海狸', '作为', '象征', '故有', '海狸', '州', '的', '别称', '瞧', '你好', '海狸', '先生', '在', '接下来', '的', '节目', '里', '我们', '会', '回答', '一些', '热门', '问题', '唯一', '一面', '不是', '长方形', '的', '旗帜', '是', '什么', '在', '旗帜', '上', '出现', '最多', '的', '动物', '是', '什么', '在', '旗帜', '上', '出现', '第二', '多', '的', '动物', '是', '什么', '等等', '你', '为什么', '挥', '白旗', '因为', '太', '欢乐', '了', '我', '投降', '了', '今天', '《', '有趣', '的', '旗帜', '》', '的', '内容', '并', '不', '有趣', '但', '十分', '重要', '旗帜', '第一课', '要', 
# ...

# %%
# Analyze Intersection between projected data and original data
